# %% [markdown]
# This program cleans the data on the prediction of well functionality.

# %%
import pandas as pd
import numpy as np
import os
import pdb
from tqdm import tqdm
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import collections
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# C:\Users\Xiaotong\Anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:35: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
os.chdir("C:\\Users\\Xiaotong\\Desktop\\wells")

# %%
def load():
    df1 = pd.read_csv("training.csv", parse_dates=["date_recorded"])
    df2 = pd.read_csv("labels.csv")
    df3 = pd.read_csv("test.csv", parse_dates=["date_recorded"])
    df =pd.merge(df2, df1, on="id", how="left")
    return df3, df

# %%
col = "installer"

# %%
train, test = load()

# %%
def fill_nan(df):
    df[col] = df[col].fillna("0")
    df[col] = df[col].str.lower()
    df[col] = df[col].replace(["not know", "not kno"], "0")
    return df

# %%
train = fill_nan(train)
test = fill_nan(test)

# %%
train["installer"].head()
# Out:
# 0          dmdd
# 1           dwe
# 2             0
# 3    finn water
# 4        bruder
# Name: installer, dtype: object

# %%
def get_composite_names(df, col):
    # list of full name entities
    fullnames_dic = {x: '' for x in df[col]}  # if len(x.split())>=2}
    fullnames_list = [x for x in df[col]]  # if len(x.split())>=2]
    for key in fullnames_dic:
        for i in range(len(key.split())):
            fullnames_dic[key] += key.split()[i][0]
    counter = collections.Counter(fullnames_list)
    return fullnames_dic, fullnames_list, counter

# %%
train_names_dic, train_names_list, train_names_counter = get_composite_names(train, col)
test_names_dic, test_names_list, test_names_counter = get_composite_names(test, col)

# %%
def fuzzymatch_one(counter, tol_partial, tol_sort, tol_set):
    """ match composite names duplicate, starting with the most frequent ones"""
    sorted_keys_desc = [x[0] for x in counter.most_common()]
    sorted_keys_asc = [x[0] for x in sorted(counter.items(), key=lambda x: x[1])]
    matched = {}
    fuzzdic = {}
    for key in tqdm(sorted_keys_desc):
        if (key not in matched) and (key not in fuzzdic):
            matched[key] = [(key, counter[key])]
            fuzzdic[key] = (key, key, counter[key])
            for item in sorted_keys_asc:
                if (item != key) and (item not in fuzzdic):
                    p0 = fuzz.ratio(key, item)
                    p1 = fuzz.partial_ratio(key, item)
                    p2 = fuzz.token_sort_ratio(key, item)
                    p3 = fuzz.token_set_ratio(key, item)
                    if (p1>tol_partial and p3>tol_set) or (p2>tol_sort and p3>tol_set):
                        matched[key].append((item, counter[item]))
                        fuzzdic[item] = (key, item, counter[item])
    return matched, fuzzdic

# %%
def hand_match_method1(matched, fuzzdic, key_list, value):
    for key in key_list:
        fuzzdic[key] = (value, key, fuzzdic[key][2]) 
        matched[value].append((key, fuzzdic[key][2]))
        if key in matched:
            for key2 in matched[key]:
                fuzzdic[key2[0]] = (value, key2[0], fuzzdic[key2[0]][2])
            del matched[key]
    return matched, fuzzdic

def hand_match_method2(matched, fuzzdic, value, string):
    for key in fuzzdic:
        if (string in fuzzdic[key][0]) and (key != value):
            fuzzdic[key] = (value, key, fuzzdic[key][2])
            matched[value].append((key, fuzzdic[key][2]))
            if key in matched:
                del matched[key]
    return matched, fuzzdic

def hand_remove(matched, fuzzdic, oldkey, newkey, value):
    fuzzdic[value[0]] = (newkey, value[0], fuzzdic[value[0]][2])
    matched[oldkey].remove(value)
    if newkey in matched:
        matched[newkey].append((value[0], value[1]))
    else:
        matched[newkey] = [(value[0], value[1])]
    return matched, fuzzdic

# %%
train_match, train_fuzz = fuzzymatch_one(train_names_counter, 50, 50, 90)
# Out:
# 100%|████████████████████████████████████████| 978/978 [01:29<00:00, 10.88it/s]

# %%
train_match, train_fuzz = hand_remove(train_match, train_fuzz, "government", "local government", \
                                      ("local government", 1))
train_match, train_fuzz = hand_remove(train_match, train_fuzz, "government", "local government", \
                                      ("village government", 1))

# %%
key_list = ['rc ch', 'rc c', 'roman church', 'roman catholic', 'roman cathoric -kilomeni', \
            'roman cathoric -same', 'rc cathoric', 'rulenge diocese', 'roman catholic rulenge diocese', \
            'roman ca', 'roman cathoric and water board', 'roman', 'roman cathoric same', \
            'roman catholic rulenge diocese', 'roman ca', 'roman cathoric -kilomeni', \
            'roman cathoric -same', 'roman church', 'roman catholic', 'rcchurch/cefa']
value = 'rc church'
train_match, train_fuzz = hand_match_method1(train_match, train_fuzz, key_list, value)

key_list = ['central govt', 'centr', 'tanzania government', 'tcrs /government', 'concern /government', \
            'adra /government', 'ministry of water', 'ministry of healthy', 'idara ya maji', 'wizara ya maji', \
            'gove', 'wachina', 'kuwait', 'kuwit']
value = 'government'
train_match, train_fuzz = hand_match_method1(train_match, train_fuzz, key_list, value)

key_list = ['consultant engineer', 'citizen engine', 'howard and humfrey consultant']
value = 'consulting engineer'
train_match, train_fuzz = hand_match_method1(train_match, train_fuzz, key_list, value)

key_list = ['local te', 'local contract', 'local fundi', 'local technical tec', 'local technical']
value = 'local  technician'
train_match, train_fuzz = hand_match_method1(train_match, train_fuzz, key_list, value)

key_list = ['sengerema water department', 'halmashauri ya wilaya sikonge', 'region water department', \
            'district water depar', 'distri', 'kigoma municipal']
value = 'local government'
train_match, train_fuzz = hand_match_method1(train_match, train_fuzz, key_list, value)

key_list = ['wananchi', 'village']
value = 'village council'
train_match, train_fuzz = hand_match_method1(train_match, train_fuzz, key_list, value)

key_list = ['priva', 'mzee shekhe', 'mzee ole', 'mzee maisha', 'mzee chacha', 'chacha', 'mzee kizunda', \
            'mzee matiti edwin']
value = 'private'
train_match, train_fuzz = hand_match_method1(train_match, train_fuzz, key_list, value)

key_list = ['finw', 'finwater', 'finwter']
value = 'fini water'
train_match, train_fuzz = hand_match_method1(train_match, train_fuzz, key_list, value)

key_list = ['unisef']
value = 'unicef'
train_match, train_fuzz = hand_match_method1(train_match, train_fuzz, key_list, value)

key_list = ['kkt']
value = 'kkkt'
train_match, train_fuzz = hand_match_method1(train_match, train_fuzz, key_list, value)

key_list = ['would bank', 'mileniam project']
value = 'world bank'
train_match, train_fuzz = hand_match_method1(train_match, train_fuzz, key_list, value)

string = 'local t'
value = 'kkkt church'
train_match, train_fuzz = hand_match_method2(train_match, train_fuzz, value, string)

string = 'italy'
value = 'italian government'
train_match, train_fuzz = hand_match_method2(train_match, train_fuzz, value, string)

string = 'would vission'
value = 'world vision'
train_match, train_fuzz = hand_match_method2(train_match, train_fuzz, value, string)

string = 'china henan contractor'
value = 'china henan construction'
train_match, train_fuzz = hand_match_method2(train_match, train_fuzz, value, string)

string = 'plan int'
value = 'plan internationa'
train_match, train_fuzz = hand_match_method2(train_match, train_fuzz, value, string)

string = 'rotery c'
value = 'rotary club'
train_match, train_fuzz = hand_match_method2(train_match, train_fuzz, value, string)

# %%
train_match, train_fuzz = hand_remove(train_match, train_fuzz, "government", "foreign government", \
                                      ('italy government', 1))

# %%
train_match, train_fuzz = hand_remove(train_match, train_fuzz, "government", "foreign government", \
                                      ('italian government', 2))
train_match, train_fuzz = hand_remove(train_match, train_fuzz, "government", "foreign government", \
                                      ('japan government', 1))
train_match, train_fuzz = hand_remove(train_match, train_fuzz, "government", "foreign government", \
                                      ('belgiam government', 2))
train_match, train_fuzz = hand_remove(train_match, train_fuzz, "government", "foreign government", \
                                      ('finland government', 7))
train_match, train_fuzz = hand_remove(train_match, train_fuzz, "government", "foreign government", \
                                      ('kuwait', 65))
train_match, train_fuzz = hand_remove(train_match, train_fuzz, "government", "foreign government", \
                                      ('kuwit', 1))

# %%
check = {key: value for key, value in train_match.items() if type(value)!=str}
[x for x in check.values()]
# Out:
# [[('dwe', 4351),
#   ('ubalozi wa marekani/dwe', 1),
#   ('consultant and dwe', 1),
#   ('lgsp/dwe', 1),
#   ('dwe/', 1),
#   ('water aid/dwe', 3),
#   ('dwe}', 7),
#   ('rwe/dwe', 12),
#   ('kkkt _ konde and dwe', 43)],
#  [('0', 1081)],
#  [('government', 476),
#   ('colonial government', 1),
#   ('british colonial government', 1),
#   ('cebtral government', 1),
#   ('tcrs /government', 1),
#   ('adra /government', 1),
#   ('central government/tlc', 1),
#   ('concern /government', 2),
#   ('isf/government', 4),
#   ('tanzania government', 4),
#   ('cipro/government', 5),
#   ('central government', 170),
#   ('central govt', 37),
#   ('centr', 33),
#   ('tanzania government', 4),
#   ('tcrs /government', 1),
#   ('concern /government', 2),
#   ('adra /government', 1),
#   ('ministry of water', 6),
#   ('ministry of healthy', 1),
#   ('idara ya maji', 32),
#   ('wizara ya maji', 28),
#   ('gove', 54),
#   ('wachina', 22)],
#  [('hesawa', 373), ('heasawa', 1)],
#  [('rwe', 292),
#   ('rwe/ community', 1),
#   ('rwe/community', 1),
#   ('rwe community', 1),
#   ('rwe /community', 2)],
#  [('commu', 289), ('commun', 1)],
#  [('danida', 256), ('danid', 162)],
#  [('kkkt', 225),
#   ('kkkt imbaseny', 1),
#   ('kkkt yeriko', 1),
#   ('kkkt kolila', 1),
#   ('kkkt mso', 1),
#   ('kkkt church s', 1),
#   ('kkkt-dioces ya pare', 2),
#   ('kkkt church', 19),
#   ('kkt', 8)],
#  [('district council', 220),
#   ('district  council', 1),
#   ('council', 1),
#   ('mbunge / district council', 1),
#   ('district counci', 1),
#   ('mbozi district council', 2)],
#  [('tcrs', 180),
#   ('tassaf /tcrs', 1),
#   ('tcrs /twesa', 1),
#   ('tcrs/village community', 1),
#   ('tcrs a', 1),
#   ('tassaf/ tcrs', 1),
#   ('cipro/care/tcrs', 1),
#   ('tcrs /care', 2)],
#  [('world vision', 168),
#   ('world vision & community', 1),
#   ('world vission', 2),
#   ('world', 33),
#   ('would vission', 1)],
#  [('ces', 155)],
#  [('gover', 142), ('rc church/central gover', 4), ('govern', 5)],
#  [('community', 135),
#   ('dads/village community', 1),
#   ('mtuwasa and community', 1),
#   ('twesa/ community', 1),
#   ('tasaf/village community', 1),
#   ('tlc/community', 1),
#   ('ngiresi village community', 2),
#   ('killflora /community', 2),
#   ('olgilai village community', 2),
#   ('oldadai village community', 3),
#   ('killflora/ community', 3),
#   ('adra/ community', 4),
#   ('summit for water/community', 4),
#   ('sekei village community', 5),
#   ('adra /community', 7),
#   ('village community', 8),
#   ('adra/community', 13),
#   ('communit', 15)],
#  [('tasaf', 112), ('tasaf/dmdd', 3), ('tassaf', 16)],
#  [('dmdd', 100), ('dmdd/solider', 1)],
#  [('wedeco', 100), ('wedeco/wessons', 2)],
#  [('amref', 95)],
#  [('lga', 93), ('lga an', 1)],
#  [('norad', 90), ('norad/', 2)],
#  [('da', 90)],
#  [('fini water', 81),
#   ('water', 13),
#   ('fin water', 23),
#   ('finw', 59),
#   ('finwater', 21),
#   ('finwter', 1)],
#  [('twesa', 79)],
#  [('wu', 76)],
#  [('acra', 68)],
#  [('unicef', 68), ('uncef', 1), ('unisef', 21)],
#  [('jaica', 67), ('jaica co', 1)],
#  [('villagers', 65)],
#  [('sema', 63),
#   ('water /sema', 1),
#   ('water  aid/sema', 2),
#   ('udc/sema', 3),
#   ('sema co ltd', 4),
#   ('water aid/sema', 7),
#   ('water aid /sema', 13)],
#  [('dw', 62), ('dw#', 1)],
#  [('kiliwater', 61), ('kiliwater r', 1), ('kili water', 7), ('kilwater', 8)],
#  [('shipo', 58)],
#  [('rc church', 55),
#   ('cefa/ rc church', 1),
#   ('rc churc', 3),
#   ('rc', 45),
#   ('rc ch', 19),
#   ('rc c', 4),
#   ('roman church', 4),
#   ('roman catholic', 5),
#   ('roman cathoric -kilomeni', 2),
#   ('roman cathoric -same', 2),
#   ('rc cathoric', 1),
#   ('rulenge diocese', 1),
#   ('roman catholic rulenge diocese', 1),
#   ('roman ca', 1),
#   ('roman cathoric and water board', 1),
#   ('roman', 25),
#   ('roman cathoric same', 1),
#   ('roman catholic rulenge diocese', 1),
#   ('roman ca', 1),
#   ('roman cathoric -kilomeni', 2),
#   ('roman cathoric -same', 2),
#   ('roman church', 4),
#   ('roman catholic', 5),
#   ('rcchurch/cefa', 6)],
#  [('oxfam', 54), ('oxfarm', 25)],
#  [('handeni trunk main(', 52), ('handeni trunk main', 3)],
#  [('magadini-makiwaru wa', 51), ('wa', 13)],
#  [('lawatefuka water sup', 49)],
#  [('world bank', 49), ('would bank', 5), ('mileniam project', 7)],
#  [('mission', 48), ('grail mission', 2), ('rc/mission', 2)],
#  [('wvt', 48), ('wvt nakombo adp', 1)],
#  [('dwsp', 47)],
#  [('dh', 44)],
#  [('adra', 42)],
#  [('fw', 41)],
#  [('private', 41),
#   ('private technician', 1),
#   ('private institutions', 1),
#   ('privat', 1),
#   ('priva', 24),
#   ('mzee shekhe', 1),
#   ('mzee ole', 1),
#   ('mzee maisha', 1),
#   ('mzee chacha', 1),
#   ('chacha', 1),
#   ('mzee kizunda', 1),
#   ('mzee matiti edwin', 1)],
#  [('mwe', 41), ('mwe &', 17)],
#  [('district water department', 35)],
#  [('consulting engineer', 34),
#   ('consuting engineer', 5),
#   ('consultant engineer', 3),
#   ('citizen engine', 2),
#   ('howard and humfrey consultant', 2)],
#  [('artisan', 34), ('artsan', 1), ('atisan', 1)],
#  [('isf', 33), ('isf/tacare', 5)],
#  [('is', 33)],
#  [('tardo', 31)],
#  [('rwssp', 31)],
#  [('jica', 31)],
#  [('ki', 30)],
#  [('ir', 29)],
#  [('ddca', 28)],
#  [('he', 28)],
#  [('cefa', 27), ('rcchurch/cefa', 6)],
#  [('lwi', 27)],
#  [('vwc', 27)],
#  [('twe', 27)],
#  [('water aid', 26), ('water  aid', 3)],
#  [('muwsa', 25), ('muwasa', 10)],
#  [('water board', 25), ('roman cathoric and water board', 1)],
#  [('aict', 24)],
#  [('angli', 23)],
#  [('dawasco', 23)],
#  [('ded', 21)],
#  [('mdrdp', 20)],
#  [('village council', 18),
#   ('village council /rc', 1),
#   ('village counil', 2),
#   ('village  council', 2),
#   ('village', 3),
#   ('wananchi', 44),
#   ('village', 3)],
#  [('hsw', 18)],
#  [('rdc', 18)],
#  [('co', 18),
#   ('winnin spirit co', 1),
#   ('simba co', 1),
#   ('jandu plumber  co', 1),
#   ('juin  co', 1),
#   ('mlaki  co', 1),
#   ('china co.', 1),
#   ('lindala co', 1),
#   ('hjk co ltd', 1),
#   ('active tank co', 2),
#   ('jlh co ltd', 2),
#   ('nyakilangani  co', 2),
#   ('nyakilangani co', 2),
#   ('kalago enterprises co.ltd', 3),
#   ('mlaki co', 3),
#   ('naishu construction co. ltd', 6),
#   ('juin co', 7),
#   ('jandu plumber co', 12)],
#  [('tlc', 17)],
#  [('gen', 17)],
#  [('mtn', 16)],
#  [('h', 16), ('h/kijiji', 1)],
#  [('plan internationa', 15), ('plan int', 5)],
#  [('do', 15)],
#  [('go', 15)],
#  [('villa', 14), ('villag', 4)],
#  [('missi', 14)],
#  [('bgm', 14)],
#  [('wb', 14)],
#  [('cjejow construction', 13)],
#  [('geotan', 13)],
#  [('local  technician', 13),
#   ('local l technician', 1),
#   ('local technician', 8),
#   ('local te', 16),
#   ('local contract', 7),
#   ('local fundi', 3),
#   ('local technical tec', 1),
#   ('local technical', 1)],
#  [('cbhcc', 13)],
#  [('si', 12)],
#  [('oikos e .africa', 12), ('oikos e. africa', 1), ('oikos e.afrika', 1)],
#  [('st', 12)],
#  [('jbg', 12)],
#  [('cons', 12)],
#  [('ncaa', 12)],
#  [('dhv', 12)],
#  [('mi', 12)],
#  [('ga', 12)],
#  [('kalta', 12)],
#  [('kadp', 11)],
#  [('shawasa', 11)],
#  [('vtecos', 11), ('vitecos', 1)],
#  [('wanan', 11)],
#  [('un', 11), ('un one', 1)],
#  [('kuwasa', 11)],
#  [('ccec', 11)],
#  [('losaa-kia water supp', 11)],
#  [('marafip', 11)],
#  [('grumeti', 11)],
#  [('lvia', 11)],
#  [('gtz', 10)],
#  [('chamavita', 10)],
#  [('solidame', 10)],
#  [('cdtf', 10)],
#  [('mbunge', 10)],
#  [('chur', 10)],
#  [('cmsr', 10)],
#  [('po', 10)],
#  [('concern', 10)],
#  [('bruder', 9)],
#  [('tdft', 9)],
#  [('ma', 9)],
#  [('wateraid', 9)],
#  [('kalitasi', 9)],
#  [('accra', 9)],
#  [('kidp', 9)],
#  [('tuwasa', 9), ('mtuwasa', 5)],
#  [('ka', 9)],
#  [('songa', 9)],
#  [('ics', 9)],
#  [('tredep', 9), ('redep', 2)],
#  [('the desk and chair foundat', 9),
#   ('the desk and chair foundatio', 1),
#   ('desk', 1)],
#  [('tanapa', 9), ('tanap', 2)],
#  [('finn water', 8)],
#  [('idydc', 8)],
#  [('cosmo', 8)],
#  [('save the rain usa', 8), ('save the rain', 2)],
#  [('pet', 8), ('pet corporation ltd', 1)],
#  [('pr', 8)],
#  [('secondary', 8), ('farm 17 secondary', 1), ('igwachanya secondary', 1)],
#  [('kiuma', 7)],
#  [('hans', 7)],
#  [('kokeni', 7)],
#  [('fathe', 7)],
#  [('mamlaka ya maji ngara', 7)],
#  [('af', 7)],
#  [('shule', 7)],
#  [('serikali', 7), ('serikali ya kijiji', 2)],
#  [('shy builders', 7)],
#  [('sowasa', 7)],
#  [('happy watoto foundation', 7), ('watoto foundation', 1)],
#  [('european union', 7)],
#  [('korogwe water works', 7)],
#  [('mlade', 7)],
#  [('vifafi', 7)],
#  [('active mkm', 7)],
#  [('holland', 7)],
#  [('padep', 7)],
#  [('miziriol', 7)],
#  [('ta', 7)],
#  [('rhobi', 7)],
#  [('rw', 7)],
#  [('ja', 7)],
#  [('scott', 6)],
#  [('swiss if', 6)],
#  [('care international', 6)],
#  [('jika', 6)],
#  [('ereto', 6)],
#  [('wsdp', 6)],
#  [('idea', 6)],
#  [('tanz', 6), ('free pentecoste church of tanz', 2)],
#  [('mbiuwasa', 6)],
#  [('orien', 6)],
#  [('not known', 6)],
#  [('mpang', 6)],
#  [('cocane', 6)],
#  [('hydrotec', 6)],
#  [('rotary club', 5), ('rotery c', 3)],
#  [('ifad', 5)],
#  [('kuamu', 5)],
#  [('benguka', 5)],
#  [('ai', 5)],
#  [('atigh buildings', 5)],
#  [('rwsp', 5)],
#  [('mosque', 5), ('mosque bugula', 1)],
#  [('ce', 5)],
#  [('msabi', 5)],
#  [('re', 5)],
#  [('cg', 5), ('cg/rc', 3)],
#  [('kim kim construction', 5)],
#  [('gwasco l', 5), ('gwasco', 1)],
#  [('duwas', 5)],
#  [('hapa singida', 5)],
#  [('abasia', 5)],
#  [('mw', 5)],
#  [('bsf', 5)],
#  [('inter', 5)],
#  [('quwkwin', 4)],
#  [('qwickwin', 4)],
#  [('sda', 4)],
#  [('w', 4), ('w.d &', 1), ('w.d $', 1), ('w/', 2)],
#  [('jicks', 4)],
#  [('pit cooperation  ltd', 4)],
#  [('tulawaka gold mine', 4)],
#  [('mackd', 4)],
#  [('red cross', 4)],
#  [('dwr', 4)],
#  [('nora', 4)],
#  [('konoike', 4)],
#  [('adp', 4), ('adp busangi', 4)],
#  [('efg', 4)],
#  [('ridep', 4), ('tridep', 2)],
#  [('wd and id', 4)],
#  [('maswi company', 4), ('maswi', 4)],
#  [('the isla', 4)],
#  [('wwf', 4), ('wwf/', 1)],
#  [('ilct', 4)],
#  [('ndanda missions', 4)],
#  [('sia ltd', 4)],
#  [('tanzania', 4),
#   ('tanzania and egypt cooperati', 1),
#   ('africa muslum agence tanzania', 1),
#   ('canada na tanzania', 3)],
#  [('tpp trustmoshi', 4)],
#  [('tahea', 4)],
#  [('part', 4)],
#  [('cartas', 4), ('caritas', 2)],
#  [('wo', 4)],
#  [('grobal resource alliance', 3)],
#  [('lva ltd', 3)],
#  [('mviwa', 3)],
#  [('m', 3)],
#  [('gain', 3)],
#  [('kirdep', 3)],
#  [('hw/rc', 3)],
#  [('kmcl', 3)],
#  [('ac', 3)],
#  [('individuals', 3), ('individual', 1)],
#  [('tabora municipal council', 3)],
#  [('prf', 3)],
#  [('hpa', 3)],
#  [('cobashec', 3)],
#  [('besada', 3)],
#  [('suleman idd', 3)],
#  [('kilwa company', 3)],
#  [('masjid', 3)],
#  [('chiko', 3), ('chiko inn', 1)],
#  [('consultant', 3),
#   ('howard and humfrey consultant', 2),
#   ('consultant engineer', 3)],
#  [('ml appro', 3)],
#  [('action aid', 3)],
#  [('songea district coun', 3), ('coun', 1), ('sangea district coun', 2)],
#  [('kanisa', 3)],
#  [('tawasa', 3)],
#  [('cipro/care', 3), ('cipro', 1)],
#  [('lamp', 3)],
#  [('fpct church', 3), ('fpct', 2)],
#  [('counc', 3)],
#  [('ham', 3)],
#  [('mkuyu', 3)],
#  [('tltc', 3)],
#  [('wfp', 3)],
#  [('dardo', 3)],
#  [('cosmos eng ltd', 3)],
#  [('mohamed shiyo', 3)],
#  [('dawas', 3)],
#  [('victoria drill', 3)],
#  [('cosmos engineering', 3)],
#  [('african development foundation', 3)],
#  [('nice', 3)],
#  [('halmashauri ya manispa tabora', 3)],
#  [('total landcare', 3)],
#  [('sumbaw', 3)],
#  [('ad', 3)],
#  [('hiap', 3)],
#  [('maji mugumu', 3), ('maji muguu', 1)],
#  [('action contre la faim', 3)],
#  [('mzungu paul', 3)],
#  [('kyasha enterpr', 3), ('kyasha', 2)],
#  [('brad', 3)],
#  [('saxon', 3), ('saxon building contractor', 1)],
#  [('belgij', 3)],
#  [('rhoda', 3)],
#  [('christian outrich', 3)],
#  [('rural drinking water supply', 3),
#   ('rural water supply', 1),
#   ('rural drinking water suply', 1)],
#  [('greec', 3)],
#  [('luthe', 3)],
#  [('amp contractor', 3), ('amp contract', 2)],
#  [('mamad', 3)],
#  [('wua', 3)],
#  [('bffs', 2)],
#  [('selous g', 2)],
#  [('makama construction', 2)],
#  [('tan plant ltd', 2)],
#  [('edward', 2)],
#  [('lench', 2)],
#  [('japan embassy', 2)],
#  [('samsoni', 2)],
#  [('longido sec school', 2), ('school', 1)],
#  [('p.n.r.', 2), ('p', 2)],
#  [('singida general  supplies  ltd', 2)],
#  [('kimkum', 2)],
#  [('karugendo', 2)],
#  [('crdb', 2)],
#  [('aimgold', 2), ('aimggold', 1)],
#  [('lutheran church', 2)],
#  [('pidp', 2)],
#  [('dads', 2)],
#  [('mbwambo', 2)],
#  [('tumaini fund', 2)],
#  [('nchagwa', 2)],
#  [('village govt', 2)],
#  [('makonde water supply', 2), ('makonde', 2)],
#  [('tanzakesho', 2)],
#  [('el', 2)],
#  [('institution', 2)],
#  [('nduku village', 2)],
#  [('makonde water population', 2)],
#  [('ns', 2)],
#  [('idc', 2)],
#  [('hanja lt', 2)],
#  [('rudep/', 2), ('rudep', 1)],
#  [('mzinga a', 2)],
#  [('dr.matobola', 2),
#   ('dr. matomola', 1),
#   ('dr.matomola', 1),
#   ('dr. matobola', 2)],
#  [('jeica', 2)],
#  [('suwasa', 2)],
#  [('canop', 2)],
#  [('mkongo construction', 2)],
#  [('wasso contractors', 2)],
#  [('musa', 2)],
#  [('tom', 2)],
#  [('dbfpe', 2)],
#  [('milenium', 2)],
#  [('obc', 2)],
#  [('the i', 2)],
#  [('jandu', 2), ('jandu plumber', 1)],
#  [('netherlands', 2)],
#  [('moroil', 2)],
#  [('africare', 2)],
#  [('lips', 2)],
#  [('school adminstrarion', 2)],
#  [('koica', 2)],
#  [('cuso', 2)],
#  [('mdala contractor', 2), ('mdala  contractor', 1)],
#  [('gwaseco', 2)],
#  [('desk c', 2)],
#  [('trachoma', 2)],
#  [('railway', 2)],
#  [('ardhi water well', 2)],
#  [('regional water', 2), ('regional water engineer arusha', 2)],
#  [('tag', 2)],
#  [('lawate fuka water su', 2), ('su', 1)],
#  [('sabodo', 2)],
#  [('vi', 2)],
#  [('exaud msambwa', 2)],
#  [('kalumbwa', 2)],
#  [('sacso', 2)],
#  [('mem', 2)],
#  [('vill', 2)],
#  [('kaemp', 2)],
#  [('msikiti', 2)],
#  [('unhcr', 2)],
#  [('pod', 2)],
#  [('haydom lutheran hospital', 2)],
#  [('trust', 2)],
#  [('singida yetu', 2), ('singida tetu', 1)],
#  [('goldstar', 2), ('gold star', 1)],
#  [('msf', 2)],
#  [('williamson diamond ltd', 2)],
#  [('floresta', 2)],
#  [('building works company ltd', 1)],
#  [('morovian', 1), ('morrovian', 1)],
#  [('mws', 1)],
#  [('college', 1)],
#  [('barry a.murphy', 1)],
#  [('care/crc', 1)],
#  [('malec', 1)],
#  [('machibya', 1)],
#  [('t', 1)],
#  [('anglikana', 1)],
#  [('jaic', 1)],
#  [('emanda builders', 1)],
#  [('mount meru flowers', 1)],
#  [('vttp', 1)],
#  [('tober and friends from austral', 1)],
#  [('clause workers', 1)],
#  [('romam', 1)],
#  [('ww', 1)],
#  [('uwamalu', 1)],
#  [('contr', 1)],
#  [('aqual', 1)],
#  [('serena', 1)],
#  [('sinohydro', 1)],
#  [('resolute', 1)],
#  [('envirocare', 1)],
#  [('rude', 1), ('rude/d', 1)],
#  [('recoda', 1)],
#  [('kerebuka', 1)],
#  [('childreach', 1), ('childreach international', 1)],
#  [('senapa', 1)],
#  [('uhai wa mama na mtoto', 1)],
#  [('friends church', 1)],
#  [('aar', 1)],
#  [('jerem', 1)],
#  [('kyela-morogoro', 1)],
#  [('usa embassy', 1), ('us embassy', 1)],
#  [('reginald mengi', 1)],
#  [('eagt church', 1)],
#  [('water users group', 1), ('users', 1)],
#  [('cspd', 1)],
#  [('churc', 1)],
#  [('pangaboi health centre', 1)],
#  [('nyakilangani construction', 1)],
#  [('milenia', 1)],
#  [('laurian rafaeli', 1)],
#  [('sems', 1)],
#  [('african mus', 1)],
#  [('isaboga', 1)],
#  [('adb', 1)],
#  [('ustawi', 1)],
#  [('colonies', 1)],
#  [('irevea sister', 1)],
#  [('agrikana', 1), ('angrikana', 1)],
#  [('omary dodo', 1)],
#  [('kdc', 1)],
#  [('panone', 1)],
#  [('koyi', 1)],
#  [('teak com', 1)],
#  [('zara camp', 1)],
#  [('kyariga', 1)],
#  [('mwanasukari', 1)],
#  [('rwss', 1)],
#  [('ndrdp', 1)],
#  [('nyitamboka', 1)],
#  [('maji tech', 1)],
#  [('ha', 1)],
#  [('islamic', 1)],
#  [('answar', 1), ('aswar', 1)],
#  [('atlan', 1)],
#  [('juma mwikabe', 1)],
#  [('b.a.p', 1)],
#  [('american people', 1)],
#  [('asdp', 1)],
#  [('zao water spring', 1)],
#  [('d', 1), ('d simba', 1), ('g.d&i.d', 1)],
#  [('njoocho masaine', 1)],
#  [('acord', 1)],
#  [('umfaiswary', 1)],
#  [('kiliflora', 1)],
#  [('sijm', 1)],
#  [('phase', 1)],
#  [('greinaker', 1)],
#  [('mkukuta', 1)],
#  [('ngeye', 1)],
#  [('hkpd babati', 1)],
#  [('ubungo water dept', 1)],
#  [('kilomber', 1)],
#  [('wamisionari wa kikatoriki', 1)],
#  [('individual person', 1)],
#  [('wasso companies', 1)],
#  [('smref', 1)],
#  [('vwa', 1)],
#  [('kalugendo', 1)],
#  [('sanje wa', 1)],
#  [('mlowa', 1)],
#  [('tanganyika basin', 1)],
#  [('rentobe', 1)],
#  [('md', 1)],
#  [('total land care', 1), ('total land  care', 1), ('att/total land care', 1)],
#  [('s.s.s', 1), ('u.s.a', 1)],
#  [('vcw', 1)],
#  [('kibaha town council', 1)],
#  [('tambalizeni', 1)],
#  [('makundya', 1)],
#  [('simavi', 1)],
#  [('halmashauri ya manispaa', 1)],
#  [('pentecosta kilinga', 1)],
#  [('kowi', 1)],
#  [('active kmk', 1)],
#  [('nwe', 1)],
#  [('mokiri mwita', 1)],
#  [('tanroad', 1)],
#  [('craelius', 1)],
#  [('pad', 1)],
#  [('tgts', 1)],
#  [('fida', 1)],
#  [('buguba', 1)],
#  [('iado', 1)],
#  [('dct', 1)],
#  [('village contractor', 1)],
#  [('vunjo sekondari', 1)],
#  [('quikwin', 1)],
#  [('sdg', 1)],
#  [('mowi', 1)],
#  [('sao', 1)],
#  [('goldfinder', 1)],
#  [('cotra', 1)],
#  [('mahiti', 1)],
#  [('thomas', 1)],
#  [('geita goldmain', 1)],
#  [('woyege', 1)],
#  [('miomb', 1)],
#  [('bi ndizi', 1)],
#  [('abraham palanjo', 1)],
#  [('marwa', 1), ('patrick marwa', 1)],
#  [('taqwa drilling compny', 1)],
#  [('gidion joseph', 1)],
#  [('stabex', 1)],
#  [('nicodemu mkumbwa', 1)],
#  [('george hekwe', 1)],
#  [('waingereza', 1)],
#  [('kulwa', 1)],
#  [('de &', 1)],
#  [('mr jul', 1)],
#  [('mr jenifred mbunda', 1)],
#  [('koec', 1)],
#  [('muwaza', 1)],
#  [('aveda', 1)],
#  [('ve', 1)],
#  [('miss', 1)],
#  [('sipdo', 1)],
#  [('lgcdg', 1)],
#  [('angrican', 1)],
#  [('cpro', 1)],
#  [('zaveriati chengula', 1)],
#  [('atlas company', 1)],
#  [('german missionary', 1), ('germany missionary', 1)],
#  [('yusuph kapiligi', 1)],
#  [('lions', 1), ("lion's", 1)],
#  [('robert', 1)],
#  [('water project mbawala chini', 1)],
#  [('aic', 1)],
#  [('totaland care', 1)],
#  [('mbunnge mkono', 1)],
#  [('mgolole', 1)],
#  [('hesewa', 1)],
#  [('amboni plantation', 1)],
#  [('mwika lekura water user', 1)],
#  [('mwang', 1)],
#  [('hemed islam', 1)],
#  [('baric', 1)],
#  [('maji block', 1)],
#  [('salim aliamari', 1)],
#  [('manyara construction', 1)],
#  [('losakia water supply', 1)],
#  [('mwita muremi', 1)],
#  [('tackle', 1)],
#  [('omari abdallah', 1)],
#  [('daldo', 1)],
#  [('conce', 1)],
#  [('mdrd_', 1)],
#  [('moyowosi', 1)],
#  [('living water international', 1)],
#  [('maswi drilling', 1)],
#  [('li', 1)],
#  [('dak', 1)],
#  [('rcchurch', 1)],
#  [('hima', 1)],
#  [('serens', 1)],
#  [('bridge north', 1)],
#  [('rished', 1)],
#  [('villegers', 1)],
#  [('matimo sangi', 1)],
#  [('karumba biulding company ltd', 1)],
#  [('tarangire park', 1)],
#  [('maji mengi', 1)],
#  [('mboma', 1)],
#  [('ddsa', 1)],
#  [('abdi mtili', 1)],
#  [('yumbaka engineering', 1)],
#  [('bgss', 1)],
#  [('tanza', 1)],
#  [('benjamin', 1)],
#  [('mhema', 1)],
#  [('nairobi company', 1)],
#  [('mosha', 1)],
#  [('dae al ber_uae', 1)],
#  [('totoland', 1)],
#  [('kijiji', 1)],
#  [('ci', 1)],
#  [('colony', 1)],
#  [('halmashaulu ya tarime', 1)],
#  [('mwanga town water authority', 1)],
#  [('winam construction', 1)],
#  [('dunda', 1)],
#  [('amp contracts', 1)],
#  [('mwakipesile', 1)],
#  [('conso', 1)],
#  [('menonite', 1)],
#  [('universal company', 1)],
#  [('unknown', 1)],
#  [('finland', 1)],
#  [('q-sem ltd', 1)],
#  [('magati', 1)],
#  [('china henan construction', 1),
#   ('china henan contractor', 6),
#   ('china', 1)],
#  [('morrevian', 1)],
#  [('diocese of geita', 1)],
#  [('anyemike', 1)],
#  [('gachuma ginery', 1)],
#  [('nyabasamba', 1)],
#  [('rundu man', 1)],
#  [('wazieni bilangali', 1)],
#  [('leef gold mining', 1)],
#  [('maria kala', 1)],
#  [('claver', 1)],
#  [('we', 1)],
#  [('folac', 1)],
#  [('nddp', 1)],
#  [('wama', 1)],
#  [('saboga bise makori', 1)],
#  [('bemanda', 1)],
#  [('mgaya', 1)],
#  [('rombo dalta', 1)],
#  [('ola', 1)],
#  [('nampupanga', 1)],
#  [('ikela wa', 1)],
#  [('ihehana', 1)],
#  [('mark', 1)],
#  [('mh kapuya', 1)],
#  [('act', 1)],
#  [('mambe', 1)],
#  [('umoja drilling contructo', 1), ('umoja drilling construction', 1)],
#  [('tr', 1)],
#  [('make engineering', 1)],
#  [('mjaka mtumwa', 1)],
#  [('halmashaul', 1), ('halmashauli', 1)],
#  [('schoo', 1)],
#  [('magereza', 1)],
#  [('wde', 1)],
#  [('mukwabi nyeisa', 1)],
#  [('jacks', 1)],
#  [('matyenye', 1)],
#  [('othodox church', 1)],
#  [('odc', 1)],
#  [('mazi investment', 1)],
#  [('regwa', 1)],
#  [('mack donald contractor', 1)],
#  [('bint', 1)],
#  [('chaboke contractor', 1)],
#  [('koca', 1)],
#  [('sikong', 1)],
#  [('particular', 1)],
#  [('cap', 1)],
#  [('kalebezo parish', 1)],
#  [('finida', 1)],
#  [('ben kapiligi', 1)],
#  [('ddp', 1)],
#  [('farm', 1)],
#  [('matala', 1)],
#  [('peesona', 1)],
#  [('nyanokwi', 1)],
#  [('nanra contractor', 1)],
#  [('mwibal', 1)],
#  [('ubalozi wa marekani', 1)],
#  [('pivate person', 1)],
#  [('iucn', 1)],
#  [('mchome', 1)],
#  [('adap', 1)],
#  [('the vickrey well', 1)],
#  [('no', 1)],
#  [('atufigwege mwahula', 1)],
#  [('crs', 1)],
#  [('ruben hunting', 1)],
#  [('ng', 1)],
#  [('cpps wat', 1)],
#  [('seronera', 1)],
#  [('seleman', 1)],
#  [('maidia simgaya', 1)],
#  [('mama maria', 1)],
#  [('kyagoka', 1)],
#  [('nyamongo gold mining', 1)],
#  [('abdul', 1)],
#  [('wanjoda', 1)],
#  [('kwiboni', 1)],
#  [('tasmin', 1)],
#  [('cocu', 1)],
#  [('ubung', 1)],
#  [('rafael', 1)],
#  [('dardi', 1)],
#  [('dr. natomola', 1)],
#  [('athumani swaleh', 1)],
#  [('pancrasi', 1)],
#  [('kashwa', 1)],
#  [('tanas', 1)],
#  [('coica', 1)],
#  [('tomas kasmil', 1)],
#  [('pata', 1)],
#  [('ruvuma basin', 1)],
#  [('ulanga c', 1)],
#  [('anref', 1)],
#  [('hadija makame', 1)],
#  [('cct', 1)],
#  [('mombia', 1)],
#  [('canaco', 1)],
#  [('banane', 1)],
#  [('compasion internatio', 1)],
#  [('haam', 1)],
#  [('majija charles', 1)],
#  [('o &', 1)],
#  [('livi', 1)],
#  [('local government', 1),
#   ('village government', 1),
#   ('sengerema water department', 46),
#   ('halmashauri ya wilaya sikonge', 30),
#   ('region water department', 13),
#   ('district water depar', 10),
#   ('distri', 43),
#   ('kigoma municipal', 5)],
#  [('italy government', 1),
#   ('italian government', 2),
#   ('japan government', 1),
#   ('belgiam government', 2),
#   ('finland government', 7),
#   ('kuwait', 65),
#   ('kuwit', 1)]]

# %%
train_fuzz
# Out:
# {'0': ('0', '0', 1081),
#  'aar': ('aar', 'aar', 1),
#  'abasia': ('abasia', 'abasia', 5),
#  'abdi mtili': ('abdi mtili', 'abdi mtili', 1),
#  'abdul': ('abdul', 'abdul', 1),
#  'abraham palanjo': ('abraham palanjo', 'abraham palanjo', 1),
#  'ac': ('ac', 'ac', 3),
#  'accra': ('accra', 'accra', 9),
#  'acord': ('acord', 'acord', 1),
#  'acra': ('acra', 'acra', 68),
#  'act': ('act', 'act', 1),
#  'action aid': ('action aid', 'action aid', 3),
#  'action contre la faim': ('action contre la faim',
#   'action contre la faim',
#   3),
#  'active kmk': ('active kmk', 'active kmk', 1),
#  'active mkm': ('active mkm', 'active mkm', 7),
#  'active tank co': ('co', 'active tank co', 2),
#  'ad': ('ad', 'ad', 3),
#  'adap': ('adap', 'adap', 1),
#  'adb': ('adb', 'adb', 1),
#  'adp': ('adp', 'adp', 4),
#  'adp busangi': ('adp', 'adp busangi', 4),
#  'adra': ('adra', 'adra', 42),
#  'adra /community': ('community', 'adra /community', 7),
#  'adra /government': ('government', 'adra /government', 1),
#  'adra/ community': ('community', 'adra/ community', 4),
#  'adra/community': ('community', 'adra/community', 13),
#  'af': ('af', 'af', 7),
#  'africa muslum agence tanzania': ('tanzania',
#   'africa muslum agence tanzania',
#   1),
#  'african development foundation': ('african development foundation',
#   'african development foundation',
#   3),
#  'african mus': ('african mus', 'african mus', 1),
#  'africare': ('africare', 'africare', 2),
#  'agrikana': ('agrikana', 'agrikana', 1),
#  'ai': ('ai', 'ai', 5),
#  'aic': ('aic', 'aic', 1),
#  'aict': ('aict', 'aict', 24),
#  'aimggold': ('aimgold', 'aimggold', 1),
#  'aimgold': ('aimgold', 'aimgold', 2),
#  'amboni plantation': ('amboni plantation', 'amboni plantation', 1),
#  'american people': ('american people', 'american people', 1),
#  'amp contract': ('amp contractor', 'amp contract', 2),
#  'amp contractor': ('amp contractor', 'amp contractor', 3),
#  'amp contracts': ('amp contracts', 'amp contracts', 1),
#  'amref': ('amref', 'amref', 95),
#  'angli': ('angli', 'angli', 23),
#  'anglikana': ('anglikana', 'anglikana', 1),
#  'angrican': ('angrican', 'angrican', 1),
#  'angrikana': ('agrikana', 'angrikana', 1),
#  'anref': ('anref', 'anref', 1),
#  'answar': ('answar', 'answar', 1),
#  'anyemike': ('anyemike', 'anyemike', 1),
#  'aqual': ('aqual', 'aqual', 1),
#  'ardhi water well': ('ardhi water well', 'ardhi water well', 2),
#  'artisan': ('artisan', 'artisan', 34),
#  'artsan': ('artisan', 'artsan', 1),
#  'asdp': ('asdp', 'asdp', 1),
#  'aswar': ('answar', 'aswar', 1),
#  'athumani swaleh': ('athumani swaleh', 'athumani swaleh', 1),
#  'atigh buildings': ('atigh buildings', 'atigh buildings', 5),
#  'atisan': ('artisan', 'atisan', 1),
#  'atlan': ('atlan', 'atlan', 1),
#  'atlas company': ('atlas company', 'atlas company', 1),
#  'att/total land care': ('total land care', 'att/total land care', 1),
#  'atufigwege mwahula': ('atufigwege mwahula', 'atufigwege mwahula', 1),
#  'aveda': ('aveda', 'aveda', 1),
#  'b.a.p': ('b.a.p', 'b.a.p', 1),
#  'banane': ('banane', 'banane', 1),
#  'baric': ('baric', 'baric', 1),
#  'barry a.murphy': ('barry a.murphy', 'barry a.murphy', 1),
#  'belgiam government': ('foreign government', 'belgiam government', 2),
#  'belgij': ('belgij', 'belgij', 3),
#  'bemanda': ('bemanda', 'bemanda', 1),
#  'ben kapiligi': ('ben kapiligi', 'ben kapiligi', 1),
#  'benguka': ('benguka', 'benguka', 5),
#  'benjamin': ('benjamin', 'benjamin', 1),
#  'besada': ('besada', 'besada', 3),
#  'bffs': ('bffs', 'bffs', 2),
#  'bgm': ('bgm', 'bgm', 14),
#  'bgss': ('bgss', 'bgss', 1),
#  'bi ndizi': ('bi ndizi', 'bi ndizi', 1),
#  'bint': ('bint', 'bint', 1),
#  'brad': ('brad', 'brad', 3),
#  'bridge north': ('bridge north', 'bridge north', 1),
#  'british colonial government': ('government',
#   'british colonial government',
#   1),
#  'bruder': ('bruder', 'bruder', 9),
#  'bsf': ('bsf', 'bsf', 5),
#  'buguba': ('buguba', 'buguba', 1),
#  'building works company ltd': ('building works company ltd',
#   'building works company ltd',
#   1),
#  'c': ('rc church', 'c', 1),
#  'canaco': ('canaco', 'canaco', 1),
#  'canada na tanzania': ('tanzania', 'canada na tanzania', 3),
#  'canop': ('canop', 'canop', 2),
#  'cap': ('cap', 'cap', 1),
#  'care international': ('care international', 'care international', 6),
#  'care/crc': ('care/crc', 'care/crc', 1),
#  'caritas': ('cartas', 'caritas', 2),
#  'cartas': ('cartas', 'cartas', 4),
#  'cbhcc': ('cbhcc', 'cbhcc', 13),
#  'ccec': ('ccec', 'ccec', 11),
#  'cct': ('cct', 'cct', 1),
#  'cdtf': ('cdtf', 'cdtf', 10),
#  'ce': ('ce', 'ce', 5),
#  'cebtral government': ('government', 'cebtral government', 1),
#  'cefa': ('cefa', 'cefa', 27),
#  'cefa/ rc church': ('rc church', 'cefa/ rc church', 1),
#  'centr': ('government', 'centr', 33),
#  'central government': ('government', 'central government', 170),
#  'central government/tlc': ('government', 'central government/tlc', 1),
#  'central govt': ('government', 'central govt', 37),
#  'ces': ('ces', 'ces', 155),
#  'cg': ('cg', 'cg', 5),
#  'cg/rc': ('cg', 'cg/rc', 3),
#  'ch': ('rc church', 'ch', 8),
#  'chaboke contractor': ('chaboke contractor', 'chaboke contractor', 1),
#  'chacha': ('private', 'chacha', 1),
#  'chamavita': ('chamavita', 'chamavita', 10),
#  'chiko': ('chiko', 'chiko', 3),
#  'chiko inn': ('chiko', 'chiko inn', 1),
#  'childreach': ('childreach', 'childreach', 1),
#  'childreach international': ('childreach', 'childreach international', 1),
#  'china': ('china henan construction', 'china', 1),
#  'china co.': ('co', 'china co.', 1),
#  'china henan construction': ('china henan construction',
#   'china henan construction',
#   1),
#  'china henan contractor': ('china henan construction',
#   'china henan contractor',
#   6),
#  'christian outrich': ('christian outrich', 'christian outrich', 3),
#  'chur': ('chur', 'chur', 10),
#  'churc': ('churc', 'churc', 1),
#  'ci': ('ci', 'ci', 1),
#  'cipro': ('cipro/care', 'cipro', 1),
#  'cipro/care': ('cipro/care', 'cipro/care', 3),
#  'cipro/care/tcrs': ('tcrs', 'cipro/care/tcrs', 1),
#  'cipro/government': ('government', 'cipro/government', 5),
#  'citizen engine': ('consulting engineer', 'citizen engine', 2),
#  'cjejow construction': ('cjejow construction', 'cjejow construction', 13),
#  'clause workers': ('clause workers', 'clause workers', 1),
#  'claver': ('claver', 'claver', 1),
#  'cmsr': ('cmsr', 'cmsr', 10),
#  'co': ('co', 'co', 18),
#  'cobashec': ('cobashec', 'cobashec', 3),
#  'cocane': ('cocane', 'cocane', 6),
#  'cocu': ('cocu', 'cocu', 1),
#  'coica': ('coica', 'coica', 1),
#  'college': ('college', 'college', 1),
#  'colonial government': ('government', 'colonial government', 1),
#  'colonies': ('colonies', 'colonies', 1),
#  'colony': ('colony', 'colony', 1),
#  'commu': ('commu', 'commu', 289),
#  'commun': ('commu', 'commun', 1),
#  'communit': ('community', 'communit', 15),
#  'community': ('community', 'community', 135),
#  'compasion internatio': ('compasion internatio', 'compasion internatio', 1),
#  'conce': ('conce', 'conce', 1),
#  'concern': ('concern', 'concern', 10),
#  'concern /government': ('government', 'concern /government', 2),
#  'cons': ('cons', 'cons', 12),
#  'conso': ('conso', 'conso', 1),
#  'consultant': ('consultant', 'consultant', 3),
#  'consultant and dwe': ('dwe', 'consultant and dwe', 1),
#  'consultant engineer': ('consulting engineer', 'consultant engineer', 3),
#  'consulting engineer': ('consulting engineer', 'consulting engineer', 34),
#  'consuting engineer': ('consulting engineer', 'consuting engineer', 5),
#  'contr': ('contr', 'contr', 1),
#  'cosmo': ('cosmo', 'cosmo', 8),
#  'cosmos eng ltd': ('cosmos eng ltd', 'cosmos eng ltd', 3),
#  'cosmos engineering': ('cosmos engineering', 'cosmos engineering', 3),
#  'cotra': ('cotra', 'cotra', 1),
#  'coun': ('songea district coun', 'coun', 1),
#  'counc': ('counc', 'counc', 3),
#  'council': ('district council', 'council', 1),
#  'cpps wat': ('cpps wat', 'cpps wat', 1),
#  'cpro': ('cpro', 'cpro', 1),
#  'craelius': ('craelius', 'craelius', 1),
#  'crdb': ('crdb', 'crdb', 2),
#  'crs': ('crs', 'crs', 1),
#  'cspd': ('cspd', 'cspd', 1),
#  'cuso': ('cuso', 'cuso', 2),
#  'd': ('d', 'd', 1),
#  'd simba': ('d', 'd simba', 1),
#  'da': ('da', 'da', 90),
#  'dads': ('dads', 'dads', 2),
#  'dads/village community': ('community', 'dads/village community', 1),
#  'dae al ber_uae': ('dae al ber_uae', 'dae al ber_uae', 1),
#  'dak': ('dak', 'dak', 1),
#  'daldo': ('daldo', 'daldo', 1),
#  'danid': ('danida', 'danid', 162),
#  'danida': ('danida', 'danida', 256),
#  'dardi': ('dardi', 'dardi', 1),
#  'dardo': ('dardo', 'dardo', 3),
#  'dawas': ('dawas', 'dawas', 3),
#  'dawasco': ('dawasco', 'dawasco', 23),
#  'dbfpe': ('dbfpe', 'dbfpe', 2),
#  'dct': ('dct', 'dct', 1),
#  'ddca': ('ddca', 'ddca', 28),
#  'ddp': ('ddp', 'ddp', 1),
#  'ddsa': ('ddsa', 'ddsa', 1),
#  'de &': ('de &', 'de &', 1),
#  'ded': ('ded', 'ded', 21),
#  'desk': ('the desk and chair foundat', 'desk', 1),
#  'desk c': ('desk c', 'desk c', 2),
#  'dh': ('dh', 'dh', 44),
#  'dhv': ('dhv', 'dhv', 12),
#  'diocese of geita': ('diocese of geita', 'diocese of geita', 1),
#  'distri': ('local government', 'distri', 43),
#  'district  council': ('district council', 'district  council', 1),
#  'district counci': ('district council', 'district counci', 1),
#  'district council': ('district council', 'district council', 220),
#  'district water depar': ('local government', 'district water depar', 10),
#  'district water department': ('district water department',
#   'district water department',
#   35),
#  'dmdd': ('dmdd', 'dmdd', 100),
#  'dmdd/solider': ('dmdd', 'dmdd/solider', 1),
#  'do': ('do', 'do', 15),
#  'dr. matobola': ('dr.matobola', 'dr. matobola', 2),
#  'dr. matomola': ('dr.matobola', 'dr. matomola', 1),
#  'dr. natomola': ('dr. natomola', 'dr. natomola', 1),
#  'dr.matobola': ('dr.matobola', 'dr.matobola', 2),
#  'dr.matomola': ('dr.matobola', 'dr.matomola', 1),
#  'dunda': ('dunda', 'dunda', 1),
#  'duwas': ('duwas', 'duwas', 5),
#  'dw': ('dw', 'dw', 62),
#  'dw#': ('dw', 'dw#', 1),
#  'dwe': ('dwe', 'dwe', 4351),
#  'dwe/': ('dwe', 'dwe/', 1),
#  'dwe}': ('dwe', 'dwe}', 7),
#  'dwr': ('dwr', 'dwr', 4),
#  'dwsp': ('dwsp', 'dwsp', 47),
#  'eagt church': ('eagt church', 'eagt church', 1),
#  'edward': ('edward', 'edward', 2),
#  'efg': ('efg', 'efg', 4),
#  'el': ('el', 'el', 2),
#  'emanda builders': ('emanda builders', 'emanda builders', 1),
#  'envirocare': ('envirocare', 'envirocare', 1),
#  'ereto': ('ereto', 'ereto', 6),
#  'european union': ('european union', 'european union', 7),
#  'exaud msambwa': ('exaud msambwa', 'exaud msambwa', 2),
#  'farm': ('farm', 'farm', 1),
#  'farm 17 secondary': ('secondary', 'farm 17 secondary', 1),
#  'fathe': ('fathe', 'fathe', 7),
#  'fida': ('fida', 'fida', 1),
#  'fin water': ('fini water', 'fin water', 23),
#  'fini water': ('fini water', 'fini water', 81),
#  'finida': ('finida', 'finida', 1),
#  'finland': ('finland', 'finland', 1),
#  'finland government': ('foreign government', 'finland government', 7),
#  'finn water': ('finn water', 'finn water', 8),
#  'finw': ('fini water', 'finw', 59),
#  'finwater': ('fini water', 'finwater', 21),
#  'finwter': ('fini water', 'finwter', 1),
#  'floresta': ('floresta', 'floresta', 2),
#  'folac': ('folac', 'folac', 1),
#  'fpct': ('fpct church', 'fpct', 2),
#  'fpct church': ('fpct church', 'fpct church', 3),
#  'free pentecoste church of tanz': ('tanz',
#   'free pentecoste church of tanz',
#   2),
#  'friends church': ('friends church', 'friends church', 1),
#  'fw': ('fw', 'fw', 41),
#  'g.d&i.d': ('d', 'g.d&i.d', 1),
#  'ga': ('ga', 'ga', 12),
#  'gachuma ginery': ('gachuma ginery', 'gachuma ginery', 1),
#  'gain': ('gain', 'gain', 3),
#  'geita goldmain': ('geita goldmain', 'geita goldmain', 1),
#  'gen': ('gen', 'gen', 17),
#  'george hekwe': ('george hekwe', 'george hekwe', 1),
#  'geotan': ('geotan', 'geotan', 13),
#  'german missionary': ('german missionary', 'german missionary', 1),
#  'germany missionary': ('german missionary', 'germany missionary', 1),
#  'gidion joseph': ('gidion joseph', 'gidion joseph', 1),
#  'go': ('go', 'go', 15),
#  'gold star': ('goldstar', 'gold star', 1),
#  'goldfinder': ('goldfinder', 'goldfinder', 1),
#  'goldstar': ('goldstar', 'goldstar', 2),
#  'gove': ('government', 'gove', 54),
#  'gover': ('gover', 'gover', 142),
#  'govern': ('gover', 'govern', 5),
#  'government': ('government', 'government', 476),
#  'grail mission': ('mission', 'grail mission', 2),
#  'greec': ('greec', 'greec', 3),
#  'greinaker': ('greinaker', 'greinaker', 1),
#  'grobal resource alliance': ('grobal resource alliance',
#   'grobal resource alliance',
#   3),
#  'grumeti': ('grumeti', 'grumeti', 11),
#  'gtz': ('gtz', 'gtz', 10),
#  'gwasco': ('gwasco l', 'gwasco', 1),
#  'gwasco l': ('gwasco l', 'gwasco l', 5),
#  'gwaseco': ('gwaseco', 'gwaseco', 2),
#  'h': ('h', 'h', 16),
#  'h/kijiji': ('h', 'h/kijiji', 1),
#  'ha': ('ha', 'ha', 1),
#  'haam': ('haam', 'haam', 1),
#  'hadija makame': ('hadija makame', 'hadija makame', 1),
#  'halmashaul': ('halmashaul', 'halmashaul', 1),
#  'halmashauli': ('halmashaul', 'halmashauli', 1),
#  'halmashaulu ya tarime': ('halmashaulu ya tarime',
#   'halmashaulu ya tarime',
#   1),
#  'halmashauri': ('local government', 'halmashauri', 6),
#  'halmashauri ya manispa tabora': ('halmashauri ya manispa tabora',
#   'halmashauri ya manispa tabora',
#   3),
#  'halmashauri ya manispaa': ('halmashauri ya manispaa',
#   'halmashauri ya manispaa',
#   1),
#  'halmashauri ya wilaya': ('local government', 'halmashauri ya wilaya', 1),
#  'halmashauri ya wilaya sikonge': ('local government',
#   'halmashauri ya wilaya sikonge',
#   30),
#  'ham': ('ham', 'ham', 3),
#  'handeni trunk main': ('handeni trunk main(', 'handeni trunk main', 3),
#  'handeni trunk main(': ('handeni trunk main(', 'handeni trunk main(', 52),
#  'hanja lt': ('hanja lt', 'hanja lt', 2),
#  'hans': ('hans', 'hans', 7),
#  'hapa singida': ('hapa singida', 'hapa singida', 5),
#  'happy watoto foundation': ('happy watoto foundation',
#   'happy watoto foundation',
#   7),
#  'haydom lutheran hospital': ('haydom lutheran hospital',
#   'haydom lutheran hospital',
#   2),
#  'he': ('he', 'he', 28),
#  'heasawa': ('hesawa', 'heasawa', 1),
#  'hemed islam': ('hemed islam', 'hemed islam', 1),
#  'hesawa': ('hesawa', 'hesawa', 373),
#  'hesewa': ('hesewa', 'hesewa', 1),
#  'hiap': ('hiap', 'hiap', 3),
#  'hima': ('hima', 'hima', 1),
#  'hjk co ltd': ('co', 'hjk co ltd', 1),
#  'hkpd babati': ('hkpd babati', 'hkpd babati', 1),
#  'holland': ('holland', 'holland', 7),
#  'howard and humfrey consultant': ('consulting engineer',
#   'howard and humfrey consultant',
#   2),
#  'hpa': ('hpa', 'hpa', 3),
#  'hsw': ('hsw', 'hsw', 18),
#  'hw/rc': ('hw/rc', 'hw/rc', 3),
#  'hydrotec': ('hydrotec', 'hydrotec', 6),
#  'iado': ('iado', 'iado', 1),
#  'ics': ('ics', 'ics', 9),
#  'idara': ('government', 'idara', 1),
#  'idara ya maji': ('government', 'idara ya maji', 32),
#  'idc': ('idc', 'idc', 2),
#  'idea': ('idea', 'idea', 6),
#  'idydc': ('idydc', 'idydc', 8),
#  'ifad': ('ifad', 'ifad', 5),
#  'igwachanya secondary': ('secondary', 'igwachanya secondary', 1),
#  'ihehana': ('ihehana', 'ihehana', 1),
#  'ikela wa': ('ikela wa', 'ikela wa', 1),
#  'ilct': ('ilct', 'ilct', 4),
#  'individual': ('individuals', 'individual', 1),
#  'individual person': ('individual person', 'individual person', 1),
#  'individuals': ('individuals', 'individuals', 3),
#  'institution': ('institution', 'institution', 2),
#  'inter': ('inter', 'inter', 5),
#  'ir': ('ir', 'ir', 29),
#  'irevea sister': ('irevea sister', 'irevea sister', 1),
#  'is': ('is', 'is', 33),
#  'isaboga': ('isaboga', 'isaboga', 1),
#  'isf': ('isf', 'isf', 33),
#  'isf/government': ('government', 'isf/government', 4),
#  'isf/tacare': ('isf', 'isf/tacare', 5),
#  'islamic': ('islamic', 'islamic', 1),
#  'italian government': ('foreign government', 'italian government', 2),
#  'italy government': ('foreign government', 'italy government', 1),
#  'iucn': ('iucn', 'iucn', 1),
#  'ja': ('ja', 'ja', 7),
#  'jacks': ('jacks', 'jacks', 1),
#  'jaic': ('jaic', 'jaic', 1),
#  'jaica': ('jaica', 'jaica', 67),
#  'jaica co': ('jaica', 'jaica co', 1),
#  'jandu': ('jandu', 'jandu', 2),
#  'jandu plumber': ('jandu', 'jandu plumber', 1),
#  'jandu plumber  co': ('co', 'jandu plumber  co', 1),
#  'jandu plumber co': ('co', 'jandu plumber co', 12),
#  'japan embassy': ('japan embassy', 'japan embassy', 2),
#  'japan government': ('foreign government', 'japan government', 1),
#  'jbg': ('jbg', 'jbg', 12),
#  'jeica': ('jeica', 'jeica', 2),
#  'jerem': ('jerem', 'jerem', 1),
#  'jica': ('jica', 'jica', 31),
#  'jicks': ('jicks', 'jicks', 4),
#  'jika': ('jika', 'jika', 6),
#  'jlh co ltd': ('co', 'jlh co ltd', 2),
#  'juin  co': ('co', 'juin  co', 1),
#  'juin co': ('co', 'juin co', 7),
#  'juma mwikabe': ('juma mwikabe', 'juma mwikabe', 1),
#  'ka': ('ka', 'ka', 9),
#  'kadp': ('kadp', 'kadp', 11),
#  'kaemp': ('kaemp', 'kaemp', 2),
#  'kalago enterprises co.ltd': ('co', 'kalago enterprises co.ltd', 3),
#  'kalebezo parish': ('kalebezo parish', 'kalebezo parish', 1),
#  'kalitasi': ('kalitasi', 'kalitasi', 9),
#  'kalta': ('kalta', 'kalta', 12),
#  'kalugendo': ('kalugendo', 'kalugendo', 1),
#  'kalumbwa': ('kalumbwa', 'kalumbwa', 2),
#  'kanisa': ('kanisa', 'kanisa', 3),
#  'karugendo': ('karugendo', 'karugendo', 2),
#  'karumba biulding company ltd': ('karumba biulding company ltd',
#   'karumba biulding company ltd',
#   1),
#  'kashwa': ('kashwa', 'kashwa', 1),
#  'kdc': ('kdc', 'kdc', 1),
#  'kerebuka': ('kerebuka', 'kerebuka', 1),
#  'ki': ('ki', 'ki', 30),
#  'kibaha town council': ('kibaha town council', 'kibaha town council', 1),
#  'kidp': ('kidp', 'kidp', 9),
#  'kigoma municipal': ('local government', 'kigoma municipal', 5),
#  'kijiji': ('kijiji', 'kijiji', 1),
#  'kili water': ('kiliwater', 'kili water', 7),
#  'kiliflora': ('kiliflora', 'kiliflora', 1),
#  'kiliwater': ('kiliwater', 'kiliwater', 61),
#  'kiliwater r': ('kiliwater', 'kiliwater r', 1),
#  'killflora /community': ('community', 'killflora /community', 2),
#  'killflora/ community': ('community', 'killflora/ community', 3),
#  'kilomber': ('kilomber', 'kilomber', 1),
#  'kilwa company': ('kilwa company', 'kilwa company', 3),
#  'kilwater': ('kiliwater', 'kilwater', 8),
#  'kim kim construction': ('kim kim construction', 'kim kim construction', 5),
#  'kimkum': ('kimkum', 'kimkum', 2),
#  'kirdep': ('kirdep', 'kirdep', 3),
#  'kiuma': ('kiuma', 'kiuma', 7),
#  'kkkt': ('kkkt', 'kkkt', 225),
#  'kkkt _ konde and dwe': ('dwe', 'kkkt _ konde and dwe', 43),
#  'kkkt church': ('kkkt', 'kkkt church', 19),
#  'kkkt church s': ('kkkt', 'kkkt church s', 1),
#  'kkkt imbaseny': ('kkkt', 'kkkt imbaseny', 1),
#  'kkkt kolila': ('kkkt', 'kkkt kolila', 1),
#  'kkkt mso': ('kkkt', 'kkkt mso', 1),
#  'kkkt yeriko': ('kkkt', 'kkkt yeriko', 1),
#  'kkkt-dioces ya pare': ('kkkt', 'kkkt-dioces ya pare', 2),
#  'kkt': ('kkkt', 'kkt', 8),
#  'kkt c': ('kkkt', 'kkt c', 2),
#  'kmcl': ('kmcl', 'kmcl', 3),
#  'koca': ('koca', 'koca', 1),
#  'koec': ('koec', 'koec', 1),
#  'koica': ('koica', 'koica', 2),
#  'kokeni': ('kokeni', 'kokeni', 7),
#  'konoike': ('konoike', 'konoike', 4),
#  'korogwe water works': ('korogwe water works', 'korogwe water works', 7),
#  'kowi': ('kowi', 'kowi', 1),
#  'koyi': ('koyi', 'koyi', 1),
#  'kuamu': ('kuamu', 'kuamu', 5),
#  'kulwa': ('kulwa', 'kulwa', 1),
#  'kuwait': ('foreign government', 'kuwait', 65),
#  'kuwasa': ('kuwasa', 'kuwasa', 11),
#  'kuwit': ('foreign government', 'kuwit', 1),
#  'kwiboni': ('kwiboni', 'kwiboni', 1),
#  'kyagoka': ('kyagoka', 'kyagoka', 1),
#  'kyariga': ('kyariga', 'kyariga', 1),
#  'kyasha': ('kyasha enterpr', 'kyasha', 2),
#  'kyasha enterpr': ('kyasha enterpr', 'kyasha enterpr', 3),
#  'kyela-morogoro': ('kyela-morogoro', 'kyela-morogoro', 1),
#  'lamp': ('lamp', 'lamp', 3),
#  'laurian rafaeli': ('laurian rafaeli', 'laurian rafaeli', 1),
#  'lawate fuka water su': ('lawate fuka water su', 'lawate fuka water su', 2),
#  'lawatefuka water sup': ('lawatefuka water sup', 'lawatefuka water sup', 49),
#  'leef gold mining': ('leef gold mining', 'leef gold mining', 1),
#  'lench': ('lench', 'lench', 2),
#  'lga': ('lga', 'lga', 93),
#  'lga an': ('lga', 'lga an', 1),
#  'lgcdg': ('lgcdg', 'lgcdg', 1),
#  'lgsp/dwe': ('dwe', 'lgsp/dwe', 1),
#  'li': ('li', 'li', 1),
#  'lindala co': ('co', 'lindala co', 1),
#  "lion's": ('lions', "lion's", 1),
#  'lions': ('lions', 'lions', 1),
#  'lips': ('lips', 'lips', 2),
#  'livi': ('livi', 'livi', 1),
#  'living water international': ('living water international',
#   'living water international',
#   1),
#  'local': ('local  technician', 'local', 10),
#  'local  technician': ('local  technician', 'local  technician', 13),
#  'local contract': ('local  technician', 'local contract', 7),
#  'local fundi': ('local  technician', 'local fundi', 3),
#  'local government': ('local government', 'local government', 1),
#  'local l technician': ('local  technician', 'local l technician', 1),
#  'local te': ('local  technician', 'local te', 16),
#  'local technical': ('local  technician', 'local technical', 1),
#  'local technical tec': ('local  technician', 'local technical tec', 1),
#  'local technician': ('local  technician', 'local technician', 8),
#  'longido sec school': ('longido sec school', 'longido sec school', 2),
#  'losaa-kia water supp': ('losaa-kia water supp', 'losaa-kia water supp', 11),
#  'losakia water supply': ('losakia water supply', 'losakia water supply', 1),
#  'luthe': ('luthe', 'luthe', 3),
#  'lutheran church': ('lutheran church', 'lutheran church', 2),
#  'lva ltd': ('lva ltd', 'lva ltd', 3),
#  'lvia': ('lvia', 'lvia', 11),
#  'lwi': ('lwi', 'lwi', 27),
#  'm': ('m', 'm', 3),
#  'ma': ('ma', 'ma', 9),
#  'machibya': ('machibya', 'machibya', 1),
#  'mack donald contractor': ('mack donald contractor',
#   'mack donald contractor',
#   1),
#  'mackd': ('mackd', 'mackd', 4),
#  'magadini-makiwaru wa': ('magadini-makiwaru wa', 'magadini-makiwaru wa', 51),
#  'magati': ('magati', 'magati', 1),
#  'magereza': ('magereza', 'magereza', 1),
#  'mahiti': ('mahiti', 'mahiti', 1),
#  'maidia simgaya': ('maidia simgaya', 'maidia simgaya', 1),
#  'maji block': ('maji block', 'maji block', 1),
#  'maji mengi': ('maji mengi', 'maji mengi', 1),
#  'maji mugumu': ('maji mugumu', 'maji mugumu', 3),
#  'maji muguu': ('maji mugumu', 'maji muguu', 1),
#  'maji tech': ('maji tech', 'maji tech', 1),
#  'majija charles': ('majija charles', 'majija charles', 1),
#  'makama construction': ('makama construction', 'makama construction', 2),
#  'make engineering': ('make engineering', 'make engineering', 1),
#  'makonde': ('makonde water supply', 'makonde', 2),
#  'makonde water population': ('makonde water population',
#   'makonde water population',
#   2),
#  'makonde water supply': ('makonde water supply', 'makonde water supply', 2),
#  'makundya': ('makundya', 'makundya', 1),
#  'malec': ('malec', 'malec', 1),
#  'mama maria': ('mama maria', 'mama maria', 1),
#  'mamad': ('mamad', 'mamad', 3),
#  'mambe': ('mambe', 'mambe', 1),
#  'mamlaka ya maji ngara': ('mamlaka ya maji ngara',
#   'mamlaka ya maji ngara',
#   7),
#  'manyara construction': ('manyara construction', 'manyara construction', 1),
#  'marafip': ('marafip', 'marafip', 11),
#  'maria kala': ('maria kala', 'maria kala', 1),
#  'mark': ('mark', 'mark', 1),
#  'marwa': ('marwa', 'marwa', 1),
#  'masjid': ('masjid', 'masjid', 3),
#  'maswi': ('maswi company', 'maswi', 4),
#  'maswi company': ('maswi company', 'maswi company', 4),
#  'maswi drilling': ('maswi drilling', 'maswi drilling', 1),
#  'matala': ('matala', 'matala', 1),
#  'matimo sangi': ('matimo sangi', 'matimo sangi', 1),
#  'matyenye': ('matyenye', 'matyenye', 1),
#  'mazi investment': ('mazi investment', 'mazi investment', 1),
#  'mbiuwasa': ('mbiuwasa', 'mbiuwasa', 6),
#  'mboma': ('mboma', 'mboma', 1),
#  'mbozi district council': ('district council', 'mbozi district council', 2),
#  'mbunge': ('mbunge', 'mbunge', 10),
#  'mbunge / district council': ('district council',
#   'mbunge / district council',
#   1),
#  'mbunnge mkono': ('mbunnge mkono', 'mbunnge mkono', 1),
#  'mbwambo': ('mbwambo', 'mbwambo', 2),
#  'mchome': ('mchome', 'mchome', 1),
#  'md': ('md', 'md', 1),
#  'mdala  contractor': ('mdala contractor', 'mdala  contractor', 1),
#  'mdala contractor': ('mdala contractor', 'mdala contractor', 2),
#  'mdrd_': ('mdrd_', 'mdrd_', 1),
#  'mdrdp': ('mdrdp', 'mdrdp', 20),
#  'mem': ('mem', 'mem', 2),
#  'menonite': ('menonite', 'menonite', 1),
#  'mgaya': ('mgaya', 'mgaya', 1),
#  'mgolole': ('mgolole', 'mgolole', 1),
#  'mh kapuya': ('mh kapuya', 'mh kapuya', 1),
#  'mhema': ('mhema', 'mhema', 1),
#  'mi': ('mi', 'mi', 12),
#  'milenia': ('milenia', 'milenia', 1),
#  'mileniam': ('world bank', 'mileniam', 3),
#  'mileniam project': ('world bank', 'mileniam project', 7),
#  'milenium': ('milenium', 'milenium', 2),
#  'ministry of healthy': ('government', 'ministry of healthy', 1),
#  'ministry of water': ('government', 'ministry of water', 6),
#  'ministry of water engineer': ('government', 'ministry of water engineer', 2),
#  'ministryof water': ('government', 'ministryof water', 2),
#  'miomb': ('miomb', 'miomb', 1),
#  'miss': ('miss', 'miss', 1),
#  'missi': ('missi', 'missi', 14),
#  'mission': ('mission', 'mission', 48),
#  'miziriol': ('miziriol', 'miziriol', 7),
#  'mjaka mtumwa': ('mjaka mtumwa', 'mjaka mtumwa', 1),
#  'mkongo construction': ('mkongo construction', 'mkongo construction', 2),
#  'mkukuta': ('mkukuta', 'mkukuta', 1),
#  'mkuyu': ('mkuyu', 'mkuyu', 3),
#  'ml appro': ('ml appro', 'ml appro', 3),
#  'mlade': ('mlade', 'mlade', 7),
#  'mlaki  co': ('co', 'mlaki  co', 1),
#  'mlaki co': ('co', 'mlaki co', 3),
#  'mlowa': ('mlowa', 'mlowa', 1),
#  'mohamed shiyo': ('mohamed shiyo', 'mohamed shiyo', 3),
#  'mokiri mwita': ('mokiri mwita', 'mokiri mwita', 1),
#  'mombia': ('mombia', 'mombia', 1),
#  'moroil': ('moroil', 'moroil', 2),
#  'morovian': ('morovian', 'morovian', 1),
#  'morrevian': ('morrevian', 'morrevian', 1),
#  'morrovian': ('morovian', 'morrovian', 1),
#  'mosha': ('mosha', 'mosha', 1),
#  'mosque': ('mosque', 'mosque', 5),
#  'mosque bugula': ('mosque', 'mosque bugula', 1),
#  'mount meru flowers': ('mount meru flowers', 'mount meru flowers', 1),
#  'mowi': ('mowi', 'mowi', 1),
#  'moyowosi': ('moyowosi', 'moyowosi', 1),
#  'mpang': ('mpang', 'mpang', 6),
#  'mr jenifred mbunda': ('mr jenifred mbunda', 'mr jenifred mbunda', 1),
#  'mr jul': ('mr jul', 'mr jul', 1),
#  'msabi': ('msabi', 'msabi', 5),
#  'msf': ('msf', 'msf', 2),
#  'msikiti': ('msikiti', 'msikiti', 2),
#  'mtn': ('mtn', 'mtn', 16),
#  'mtuwasa': ('tuwasa', 'mtuwasa', 5),
#  'mtuwasa and community': ('community', 'mtuwasa and community', 1),
#  'mukwabi nyeisa': ('mukwabi nyeisa', 'mukwabi nyeisa', 1),
#  'musa': ('musa', 'musa', 2),
#  'muwasa': ('muwsa', 'muwasa', 10),
#  'muwaza': ('muwaza', 'muwaza', 1),
#  'muwsa': ('muwsa', 'muwsa', 25),
#  'mviwa': ('mviwa', 'mviwa', 3),
#  'mw': ('mw', 'mw', 5),
#  'mwakipesile': ('mwakipesile', 'mwakipesile', 1),
#  'mwanasukari': ('mwanasukari', 'mwanasukari', 1),
#  'mwang': ('mwang', 'mwang', 1),
#  'mwanga town water authority': ('mwanga town water authority',
#   'mwanga town water authority',
#   1),
#  'mwe': ('mwe', 'mwe', 41),
#  'mwe &': ('mwe', 'mwe &', 17),
#  'mwibal': ('mwibal', 'mwibal', 1),
#  'mwika lekura water user': ('mwika lekura water user',
#   'mwika lekura water user',
#   1),
#  'mwita muremi': ('mwita muremi', 'mwita muremi', 1),
#  'mws': ('mws', 'mws', 1),
#  'mzee chacha': ('private', 'mzee chacha', 1),
#  'mzee kizunda': ('private', 'mzee kizunda', 1),
#  'mzee maisha': ('private', 'mzee maisha', 1),
#  'mzee matiti edwin': ('private', 'mzee matiti edwin', 1),
#  'mzee ole': ('private', 'mzee ole', 1),
#  'mzee shekhe': ('private', 'mzee shekhe', 1),
#  'mzinga a': ('mzinga a', 'mzinga a', 2),
#  'mzungu paul': ('mzungu paul', 'mzungu paul', 3),
#  'nairobi company': ('nairobi company', 'nairobi company', 1),
#  'naishu construction co. ltd': ('co', 'naishu construction co. ltd', 6),
#  'nampupanga': ('nampupanga', 'nampupanga', 1),
#  'nanra contractor': ('nanra contractor', 'nanra contractor', 1),
#  'ncaa': ('ncaa', 'ncaa', 12),
#  'nchagwa': ('nchagwa', 'nchagwa', 2),
#  'ndanda missions': ('ndanda missions', 'ndanda missions', 4),
#  'nddp': ('nddp', 'nddp', 1),
#  'ndrdp': ('ndrdp', 'ndrdp', 1),
#  'nduku village': ('nduku village', 'nduku village', 2),
#  'netherlands': ('netherlands', 'netherlands', 2),
#  'ng': ('ng', 'ng', 1),
#  'ngeye': ('ngeye', 'ngeye', 1),
#  'ngiresi village community': ('community', 'ngiresi village community', 2),
#  'nice': ('nice', 'nice', 3),
#  'nicodemu mkumbwa': ('nicodemu mkumbwa', 'nicodemu mkumbwa', 1),
#  'njoocho masaine': ('njoocho masaine', 'njoocho masaine', 1),
#  'no': ('no', 'no', 1),
#  'nora': ('nora', 'nora', 4),
#  'norad': ('norad', 'norad', 90),
#  'norad/': ('norad', 'norad/', 2),
#  'not known': ('not known', 'not known', 6),
#  'ns': ('ns', 'ns', 2),
#  'nwe': ('nwe', 'nwe', 1),
#  'nyabasamba': ('nyabasamba', 'nyabasamba', 1),
#  'nyakilangani  co': ('co', 'nyakilangani  co', 2),
#  'nyakilangani co': ('co', 'nyakilangani co', 2),
#  'nyakilangani construction': ('nyakilangani construction',
#   'nyakilangani construction',
#   1),
#  'nyamongo gold mining': ('nyamongo gold mining', 'nyamongo gold mining', 1),
#  'nyanokwi': ('nyanokwi', 'nyanokwi', 1),
#  'nyitamboka': ('nyitamboka', 'nyitamboka', 1),
#  'o &': ('o &', 'o &', 1),
#  'obc': ('obc', 'obc', 2),
#  'odc': ('odc', 'odc', 1),
#  'oikos e .africa': ('oikos e .africa', 'oikos e .africa', 12),
#  'oikos e. africa': ('oikos e .africa', 'oikos e. africa', 1),
#  'oikos e.afrika': ('oikos e .africa', 'oikos e.afrika', 1),
#  'ola': ('ola', 'ola', 1),
#  'oldadai village community': ('community', 'oldadai village community', 3),
#  'olgilai village community': ('community', 'olgilai village community', 2),
#  'omari abdallah': ('omari abdallah', 'omari abdallah', 1),
#  'omary dodo': ('omary dodo', 'omary dodo', 1),
#  'orien': ('orien', 'orien', 6),
#  'othodox church': ('othodox church', 'othodox church', 1),
#  'oxfam': ('oxfam', 'oxfam', 54),
#  'oxfarm': ('oxfam', 'oxfarm', 25),
#  'p': ('p.n.r.', 'p', 2),
#  'p.n.r.': ('p.n.r.', 'p.n.r.', 2),
#  'pad': ('pad', 'pad', 1),
#  'padep': ('padep', 'padep', 7),
#  'pancrasi': ('pancrasi', 'pancrasi', 1),
#  'pangaboi health centre': ('pangaboi health centre',
#   'pangaboi health centre',
#   1),
#  'panone': ('panone', 'panone', 1),
#  'part': ('part', 'part', 4),
#  'particular': ('particular', 'particular', 1),
#  'pata': ('pata', 'pata', 1),
#  'patrick marwa': ('marwa', 'patrick marwa', 1),
#  'peesona': ('peesona', 'peesona', 1),
#  'pentecosta kilinga': ('pentecosta kilinga', 'pentecosta kilinga', 1),
#  'pet': ('pet', 'pet', 8),
#  'pet corporation ltd': ('pet', 'pet corporation ltd', 1),
#  'phase': ('phase', 'phase', 1),
#  'pidp': ('pidp', 'pidp', 2),
#  'pit cooperation  ltd': ('pit cooperation  ltd', 'pit cooperation  ltd', 4),
#  'pivate person': ('pivate person', 'pivate person', 1),
#  'plan int': ('plan internationa', 'plan int', 5),
#  'plan internationa': ('plan internationa', 'plan internationa', 15),
#  'po': ('po', 'po', 10),
#  'pod': ('pod', 'pod', 2),
#  'pr': ('pr', 'pr', 8),
#  'prf': ('prf', 'prf', 3),
#  'priva': ('private', 'priva', 24),
#  'privat': ('private', 'privat', 1),
#  'private': ('private', 'private', 41),
#  'private institutions': ('private', 'private institutions', 1),
#  'private technician': ('private', 'private technician', 1),
#  'q-sem ltd': ('q-sem ltd', 'q-sem ltd', 1),
#  'quikwin': ('quikwin', 'quikwin', 1),
#  'quwkwin': ('quwkwin', 'quwkwin', 4),
#  'qwickwin': ('qwickwin', 'qwickwin', 4),
#  'rafael': ('rafael', 'rafael', 1),
#  'railway': ('railway', 'railway', 2),
#  'rc': ('rc church', 'rc', 45),
#  'rc c': ('rc church', 'rc c', 4),
#  'rc cathoric': ('rc church', 'rc cathoric', 1),
#  'rc ch': ('rc church', 'rc ch', 19),
#  'rc churc': ('rc church', 'rc churc', 3),
#  'rc church': ('rc church', 'rc church', 55),
#  'rc church/central gover': ('gover', 'rc church/central gover', 4),
#  'rc/mission': ('mission', 'rc/mission', 2),
#  'rcchurch': ('rcchurch', 'rcchurch', 1),
#  'rcchurch/cefa': ('rc church', 'rcchurch/cefa', 6),
#  'rdc': ('rdc', 'rdc', 18),
#  're': ('re', 're', 5),
#  'recoda': ('recoda', 'recoda', 1),
#  'red cross': ('red cross', 'red cross', 4),
#  'redep': ('tredep', 'redep', 2),
#  'reginald mengi': ('reginald mengi', 'reginald mengi', 1),
#  'region water department': ('local government',
#   'region water department',
#   13),
#  'regional water': ('regional water', 'regional water', 2),
#  'regional water engineer arusha': ('regional water',
#   'regional water engineer arusha',
#   2),
#  'regwa': ('regwa', 'regwa', 1),
#  'rentobe': ('rentobe', 'rentobe', 1),
#  'resolute': ('resolute', 'resolute', 1),
#  'rhobi': ('rhobi', 'rhobi', 7),
#  'rhoda': ('rhoda', 'rhoda', 3),
#  'ridep': ('ridep', 'ridep', 4),
#  'rished': ('rished', 'rished', 1),
#  'robert': ('robert', 'robert', 1),
#  'romam': ('romam', 'romam', 1),
#  'roman': ('rc church', 'roman', 25),
#  'roman ca': ('rc church', 'roman ca', 1),
#  'roman catholic': ('rc church', 'roman catholic', 5),
#  'roman catholic rulenge diocese': ('rc church',
#   'roman catholic rulenge diocese',
#   1),
#  'roman cathoric -kilomeni': ('rc church', 'roman cathoric -kilomeni', 2),
#  'roman cathoric -same': ('rc church', 'roman cathoric -same', 2),
#  'roman cathoric and water board': ('rc church',
#   'roman cathoric and water board',
#   1),
#  'roman cathoric same': ('rc church', 'roman cathoric same', 1),
#  'roman church': ('rc church', 'roman church', 4),
#  'rombo dalta': ('rombo dalta', 'rombo dalta', 1),
#  'rotary club': ('rotary club', 'rotary club', 5),
#  'rotery c': ('rotary club', 'rotery c', 3),
#  'ruben hunting': ('ruben hunting', 'ruben hunting', 1),
#  'rude': ('rude', 'rude', 1),
#  'rude/d': ('rude', 'rude/d', 1),
#  'rudep': ('rudep/', 'rudep', 1),
#  'rudep/': ('rudep/', 'rudep/', 2),
#  'rulenge diocese': ('rc church', 'rulenge diocese', 1),
#  'rundu man': ('rundu man', 'rundu man', 1),
#  'rural drinking water suply': ('rural drinking water supply',
#   'rural drinking water suply',
#   1),
#  'rural drinking water supply': ('rural drinking water supply',
#   'rural drinking water supply',
#   3),
#  'rural water supply': ('rural drinking water supply',
#   'rural water supply',
#   1),
#  'ruvuma basin': ('ruvuma basin', 'ruvuma basin', 1),
#  'rw': ('rw', 'rw', 7),
#  'rwe': ('rwe', 'rwe', 292),
#  'rwe /community': ('rwe', 'rwe /community', 2),
#  'rwe community': ('rwe', 'rwe community', 1),
#  'rwe/ community': ('rwe', 'rwe/ community', 1),
#  'rwe/community': ('rwe', 'rwe/community', 1),
#  'rwe/dwe': ('dwe', 'rwe/dwe', 12),
#  'rwsp': ('rwsp', 'rwsp', 5),
#  'rwss': ('rwss', 'rwss', 1),
#  'rwssp': ('rwssp', 'rwssp', 31),
#  's.s.s': ('s.s.s', 's.s.s', 1),
#  'sabodo': ('sabodo', 'sabodo', 2),
#  'saboga bise makori': ('saboga bise makori', 'saboga bise makori', 1),
#  'sacso': ('sacso', 'sacso', 2),
#  'salim aliamari': ('salim aliamari', 'salim aliamari', 1),
#  'samsoni': ('samsoni', 'samsoni', 2),
#  'sangea district coun': ('songea district coun', 'sangea district coun', 2),
#  'sanje wa': ('sanje wa', 'sanje wa', 1),
#  'sao': ('sao', 'sao', 1),
#  'save the rain': ('save the rain usa', 'save the rain', 2),
#  'save the rain usa': ('save the rain usa', 'save the rain usa', 8),
#  'saxon': ('saxon', 'saxon', 3),
#  'saxon building contractor': ('saxon', 'saxon building contractor', 1),
#  'schoo': ('schoo', 'schoo', 1),
#  'school': ('longido sec school', 'school', 1),
#  'school adminstrarion': ('school adminstrarion', 'school adminstrarion', 2),
#  'scott': ('scott', 'scott', 6),
#  'sda': ('sda', 'sda', 4),
#  'sdg': ('sdg', 'sdg', 1),
#  'secondary': ('secondary', 'secondary', 8),
#  'sekei village community': ('community', 'sekei village community', 5),
#  'seleman': ('seleman', 'seleman', 1),
#  'selous g': ('selous g', 'selous g', 2),
#  'sema': ('sema', 'sema', 63),
#  'sema co ltd': ('sema', 'sema co ltd', 4),
#  'sems': ('sems', 'sems', 1),
#  'senapa': ('senapa', 'senapa', 1),
#  'sengerema water department': ('local government',
#   'sengerema water department',
#   46),
#  'serena': ('serena', 'serena', 1),
#  'serens': ('serens', 'serens', 1),
#  'serikali': ('serikali', 'serikali', 7),
#  'serikali ya kijiji': ('serikali', 'serikali ya kijiji', 2),
#  'seronera': ('seronera', 'seronera', 1),
#  'shawasa': ('shawasa', 'shawasa', 11),
#  'shipo': ('shipo', 'shipo', 58),
#  'shule': ('shule', 'shule', 7),
#  'shy builders': ('shy builders', 'shy builders', 7),
#  'si': ('si', 'si', 12),
#  'sia ltd': ('sia ltd', 'sia ltd', 4),
#  'sijm': ('sijm', 'sijm', 1),
#  'sikong': ('sikong', 'sikong', 1),
#  'simavi': ('simavi', 'simavi', 1),
#  'simba co': ('co', 'simba co', 1),
#  'singida general  supplies  ltd': ('singida general  supplies  ltd',
#   'singida general  supplies  ltd',
#   2),
#  'singida tetu': ('singida yetu', 'singida tetu', 1),
#  'singida yetu': ('singida yetu', 'singida yetu', 2),
#  'sinohydro': ('sinohydro', 'sinohydro', 1),
#  'sipdo': ('sipdo', 'sipdo', 1),
#  'smref': ('smref', 'smref', 1),
#  'solidame': ('solidame', 'solidame', 10),
#  'songa': ('songa', 'songa', 9),
#  'songea district coun': ('songea district coun', 'songea district coun', 3),
#  'sowasa': ('sowasa', 'sowasa', 7),
#  'st': ('st', 'st', 12),
#  'stabex': ('stabex', 'stabex', 1),
#  'su': ('lawate fuka water su', 'su', 1),
#  'suleman idd': ('suleman idd', 'suleman idd', 3),
#  'sumbaw': ('sumbaw', 'sumbaw', 3),
#  'summit for water/community': ('community', 'summit for water/community', 4),
#  'suwasa': ('suwasa', 'suwasa', 2),
#  'swiss if': ('swiss if', 'swiss if', 6),
#  't': ('t', 't', 1),
#  'ta': ('ta', 'ta', 7),
#  'tabora municipal council': ('tabora municipal council',
#   'tabora municipal council',
#   3),
#  'tackle': ('tackle', 'tackle', 1),
#  'tag': ('tag', 'tag', 2),
#  'tahea': ('tahea', 'tahea', 4),
#  'tambalizeni': ('tambalizeni', 'tambalizeni', 1),
#  'tan plant ltd': ('tan plant ltd', 'tan plant ltd', 2),
#  'tanap': ('tanapa', 'tanap', 2),
#  'tanapa': ('tanapa', 'tanapa', 9),
#  'tanas': ('tanas', 'tanas', 1),
#  'tanganyika basin': ('tanganyika basin', 'tanganyika basin', 1),
#  'tanroad': ('tanroad', 'tanroad', 1),
#  'tanz': ('tanz', 'tanz', 6),
#  'tanza': ('tanza', 'tanza', 1),
#  'tanzakesho': ('tanzakesho', 'tanzakesho', 2),
#  'tanzania': ('tanzania', 'tanzania', 4),
#  'tanzania and egypt cooperati': ('tanzania',
#   'tanzania and egypt cooperati',
#   1),
#  'tanzania government': ('government', 'tanzania government', 4),
#  'taqwa drilling compny': ('taqwa drilling compny',
#   'taqwa drilling compny',
#   1),
#  'tarangire park': ('tarangire park', 'tarangire park', 1),
#  'tardo': ('tardo', 'tardo', 31),
#  'tasaf': ('tasaf', 'tasaf', 112),
#  'tasaf/dmdd': ('tasaf', 'tasaf/dmdd', 3),
#  'tasaf/village community': ('community', 'tasaf/village community', 1),
#  'tasmin': ('tasmin', 'tasmin', 1),
#  'tassaf': ('tasaf', 'tassaf', 16),
#  'tassaf /tcrs': ('tcrs', 'tassaf /tcrs', 1),
#  'tassaf/ tcrs': ('tcrs', 'tassaf/ tcrs', 1),
#  'tawasa': ('tawasa', 'tawasa', 3),
#  'tcrs': ('tcrs', 'tcrs', 180),
#  'tcrs /care': ('tcrs', 'tcrs /care', 2),
#  'tcrs /government': ('government', 'tcrs /government', 1),
#  'tcrs /twesa': ('tcrs', 'tcrs /twesa', 1),
#  'tcrs a': ('tcrs', 'tcrs a', 1),
#  'tcrs/village community': ('tcrs', 'tcrs/village community', 1),
#  'tdft': ('tdft', 'tdft', 9),
#  'teak com': ('teak com', 'teak com', 1),
#  'tgts': ('tgts', 'tgts', 1),
#  'the desk and chair foundat': ('the desk and chair foundat',
#   'the desk and chair foundat',
#   9),
#  'the desk and chair foundatio': ('the desk and chair foundat',
#   'the desk and chair foundatio',
#   1),
#  'the i': ('the i', 'the i', 2),
#  'the isla': ('the isla', 'the isla', 4),
#  'the vickrey well': ('the vickrey well', 'the vickrey well', 1),
#  'thomas': ('thomas', 'thomas', 1),
#  'tlc': ('tlc', 'tlc', 17),
#  'tlc/community': ('community', 'tlc/community', 1),
#  'tltc': ('tltc', 'tltc', 3),
#  'tober and friends from austral': ('tober and friends from austral',
#   'tober and friends from austral',
#   1),
#  'tom': ('tom', 'tom', 2),
#  'tomas kasmil': ('tomas kasmil', 'tomas kasmil', 1),
#  'total land  care': ('total land care', 'total land  care', 1),
#  'total land care': ('total land care', 'total land care', 1),
#  'total landcare': ('total landcare', 'total landcare', 3),
#  'totaland care': ('totaland care', 'totaland care', 1),
#  'totoland': ('totoland', 'totoland', 1),
#  'tpp trustmoshi': ('tpp trustmoshi', 'tpp trustmoshi', 4),
#  'tr': ('tr', 'tr', 1),
#  'trachoma': ('trachoma', 'trachoma', 2),
#  'tredep': ('tredep', 'tredep', 9),
#  'tridep': ('ridep', 'tridep', 2),
#  'trust': ('trust', 'trust', 2),
#  'tulawaka gold mine': ('tulawaka gold mine', 'tulawaka gold mine', 4),
#  'tumaini fund': ('tumaini fund', 'tumaini fund', 2),
#  'tuwasa': ('tuwasa', 'tuwasa', 9),
#  'twe': ('twe', 'twe', 27),
#  'twesa': ('twesa', 'twesa', 79),
#  'twesa/ community': ('community', 'twesa/ community', 1),
#  'u.s.a': ('s.s.s', 'u.s.a', 1),
#  'ubalozi wa marekani': ('ubalozi wa marekani', 'ubalozi wa marekani', 1),
#  'ubalozi wa marekani/dwe': ('dwe', 'ubalozi wa marekani/dwe', 1),
#  'ubung': ('ubung', 'ubung', 1),
#  'ubungo water dept': ('ubungo water dept', 'ubungo water dept', 1),
#  'udc/sema': ('sema', 'udc/sema', 3),
#  'uhai wa mama na mtoto': ('uhai wa mama na mtoto',
#   'uhai wa mama na mtoto',
#   1),
#  'ulanga c': ('ulanga c', 'ulanga c', 1),
#  'umfaiswary': ('umfaiswary', 'umfaiswary', 1),
#  'umoja drilling construction': ('umoja drilling contructo',
#   'umoja drilling construction',
#   1),
#  'umoja drilling contructo': ('umoja drilling contructo',
#   'umoja drilling contructo',
#   1),
#  'un': ('un', 'un', 11),
#  'un one': ('un', 'un one', 1),
#  'uncef': ('unicef', 'uncef', 1),
#  'unhcr': ('unhcr', 'unhcr', 2),
#  'unicef': ('unicef', 'unicef', 68),
#  'unisef': ('unicef', 'unisef', 21),
#  'universal company': ('universal company', 'universal company', 1),
#  'unknown': ('unknown', 'unknown', 1),
#  'us embassy': ('usa embassy', 'us embassy', 1),
#  'usa embassy': ('usa embassy', 'usa embassy', 1),
#  'users': ('water users group', 'users', 1),
#  'ustawi': ('ustawi', 'ustawi', 1),
#  'uwamalu': ('uwamalu', 'uwamalu', 1),
#  'vcw': ('vcw', 'vcw', 1),
#  've': ('ve', 've', 1),
#  'vi': ('vi', 'vi', 2),
#  'victoria drill': ('victoria drill', 'victoria drill', 3),
#  'vifafi': ('vifafi', 'vifafi', 7),
#  'vill': ('vill', 'vill', 2),
#  'villa': ('villa', 'villa', 14),
#  'villag': ('villa', 'villag', 4),
#  'village': ('village council', 'village', 3),
#  'village  council': ('village council', 'village  council', 2),
#  'village community': ('community', 'village community', 8),
#  'village contractor': ('village contractor', 'village contractor', 1),
#  'village council': ('village council', 'village council', 18),
#  'village council /rc': ('village council', 'village council /rc', 1),
#  'village counil': ('village council', 'village counil', 2),
#  'village government': ('local government', 'village government', 1),
#  'village govt': ('village govt', 'village govt', 2),
#  'villagers': ('villagers', 'villagers', 65),
#  'villegers': ('villegers', 'villegers', 1),
#  'vitecos': ('vtecos', 'vitecos', 1),
#  'vtecos': ('vtecos', 'vtecos', 11),
#  'vttp': ('vttp', 'vttp', 1),
#  'vunjo sekondari': ('vunjo sekondari', 'vunjo sekondari', 1),
#  'vwa': ('vwa', 'vwa', 1),
#  'vwc': ('vwc', 'vwc', 27),
#  'w': ('w', 'w', 4),
#  'w.d $': ('w', 'w.d $', 1),
#  'w.d &': ('w', 'w.d &', 1),
#  'w/': ('w', 'w/', 2),
#  'wa': ('magadini-makiwaru wa', 'wa', 13),
#  'wachina': ('government', 'wachina', 22),
#  'waingereza': ('waingereza', 'waingereza', 1),
#  'wama': ('wama', 'wama', 1),
#  'wamisionari wa kikatoriki': ('wamisionari wa kikatoriki',
#   'wamisionari wa kikatoriki',
#   1),
#  'wanan': ('wanan', 'wanan', 11),
#  'wananchi': ('village council', 'wananchi', 44),
#  'wanjoda': ('wanjoda', 'wanjoda', 1),
#  'wasso companies': ('wasso companies', 'wasso companies', 1),
#  'wasso contractors': ('wasso contractors', 'wasso contractors', 2),
#  'water': ('fini water', 'water', 13),
#  'water  aid': ('water aid', 'water  aid', 3),
#  'water  aid/sema': ('sema', 'water  aid/sema', 2),
#  'water /sema': ('sema', 'water /sema', 1),
#  'water aid': ('water aid', 'water aid', 26),
#  'water aid /sema': ('sema', 'water aid /sema', 13),
#  'water aid/dwe': ('dwe', 'water aid/dwe', 3),
#  'water aid/sema': ('sema', 'water aid/sema', 7),
#  'water board': ('water board', 'water board', 25),
#  'water department': ('local government', 'water department', 1),
#  'water project mbawala chini': ('water project mbawala chini',
#   'water project mbawala chini',
#   1),
#  'water users group': ('water users group', 'water users group', 1),
#  'wateraid': ('wateraid', 'wateraid', 9),
#  'watoto foundation': ('happy watoto foundation', 'watoto foundation', 1),
#  'wazieni bilangali': ('wazieni bilangali', 'wazieni bilangali', 1),
#  'wb': ('wb', 'wb', 14),
#  'wd and id': ('wd and id', 'wd and id', 4),
#  'wde': ('wde', 'wde', 1),
#  'we': ('we', 'we', 1),
#  'wedeco': ('wedeco', 'wedeco', 100),
#  'wedeco/wessons': ('wedeco', 'wedeco/wessons', 2),
#  'wfp': ('wfp', 'wfp', 3),
#  'williamson diamond ltd': ('williamson diamond ltd',
#   'williamson diamond ltd',
#   2),
#  'winam construction': ('winam construction', 'winam construction', 1),
#  'winnin spirit co': ('co', 'winnin spirit co', 1),
#  'wizara': ('government', 'wizara', 3),
#  'wizara ya maji': ('government', 'wizara ya maji', 28),
#  'wo': ('wo', 'wo', 4),
#  'world': ('world vision', 'world', 33),
#  'world bank': ('world bank', 'world bank', 49),
#  'world vision': ('world vision', 'world vision', 168),
#  'world vision & community': ('world vision', 'world vision & community', 1),
#  'world vission': ('world vision', 'world vission', 2),
#  'would bank': ('world bank', 'would bank', 5),
#  'would vission': ('world vision', 'would vission', 1),
#  'woyege': ('woyege', 'woyege', 1),
#  'wsdp': ('wsdp', 'wsdp', 6),
#  'wu': ('wu', 'wu', 76),
#  'wua': ('wua', 'wua', 3),
#  'wvt': ('wvt', 'wvt', 48),
#  'wvt nakombo adp': ('wvt', 'wvt nakombo adp', 1),
#  'ww': ('ww', 'ww', 1),
#  'wwf': ('wwf', 'wwf', 4),
#  'wwf/': ('wwf', 'wwf/', 1),
#  'yumbaka engineering': ('yumbaka engineering', 'yumbaka engineering', 1),
#  'yusuph kapiligi': ('yusuph kapiligi', 'yusuph kapiligi', 1),
#  'zao water spring': ('zao water spring', 'zao water spring', 1),
#  'zara camp': ('zara camp', 'zara camp', 1),
#  'zaveriati chengula': ('zaveriati chengula', 'zaveriati chengula', 1)}

# %%
def match_acronyms(matched, fuzzdic, df):
    
    return

# %%
# train_histo = np.histogram(list(trainnames_counter.values()), bins=len(trainnames_counter.values()))
# test_histo = np.histogram(list(testnames_counter.values()), bins=len(testnames_counter.values()))

# %%
# plt.bar(train_histo[1][:-1], train_histo[0])
# plt.ylim((0,30))
# plt.xlim(0,100)
# plt.xlabel("number of occurences of a name")
# plt.ylabel("number of names that occur x times")

# %%
# plt.bar(test_histo[1][:-1], test_histo[0])
# plt.ylim((0,30))
# plt.xlim(0,100)
# plt.xlabel("number of occurences of a name")
# plt.ylabel("number of names that occur x times")
